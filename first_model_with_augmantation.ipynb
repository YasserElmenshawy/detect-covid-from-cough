# %% [markdown]
# <a href="https://colab.research.google.com/github/YasserElmenshawy/detect-covid-from-gough/blob/main/first_model_with_augmantation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import Sequential,Model
from keras.layers import concatenate,Activation, Dense, Dropout, Conv2D, Flatten, MaxPooling2D, GlobalMaxPooling2D, GlobalAveragePooling1D, AveragePooling2D, Input, Add, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import model_from_json
from sklearn.metrics import roc_curve
from keras.utils import np_utils
from tqdm import tqdm
import pandas as pd
import numpy as np
import librosa 
import librosa.display
import pylab
import cv2
import os

# %%
# !git clone https://github.com/iiscleap/Coswara-Data.git
# Out:
# Cloning into 'Coswara-Data'...
# remote: Enumerating objects: 798, done.
# remote: Total 798 (delta 0), reused 0 (delta 0), pack-reused 798
# Receiving objects: 100% (798/798), 15.97 GiB | 13.76 MiB/s, done.
# Resolving deltas: 100% (310/310), done.
# Checking out files: 100% (202/202), done.

# %%
rt_dir = '/content/Coswara-Data'
import glob
for each in os.listdir(rt_dir):
    if os.path.isdir(os.path.join(rt_dir,each)) and each != '.git':
        print(each)
        # !cat {os.path.join(rt_dir, each,'')}*.tar.gz.* > {os.path.join(rt_dir, each,'')}combined_file.tar.gz
        # !tar -xzf {os.path.join(rt_dir, each,'')}combined_file.tar.gz -C {rt_dir}
subset = glob.glob('/content/Coswara-Data/*/*.tar.gz.*') + glob.glob('/content/Coswara-Data/*/combined_data.tar.gz')
[os.remove(x) for x in subset];
# Out:
# 20220224
# 20210206
# 20200413
# 20200824
# 20200416
# 20200930
# 20200504
# 20210618
# 20200525
# 20210406
# 20210914
# 20200505
# 20200814
# 20210630
# 20200707
# 20200919
# 20200901
# 20200424
# 20210714
# 20201031
# 20210816
# 20210930
# 20210419
# 20200820
# 20210426
# 20201012
# 20200803
# 20220116
# 20200604
# 20210507
# 20210523
# 20200720
# 20210603
# 20200430
# 20200418
# 20200415
# 20200417
# 20201221
# 20200419
# 20200911
# 20200502
# 20201130
# 20210830

# %%
# !wget https://zenodo.org/record/4048312/files/public_dataset.zip?download=1
# !mv public_dataset.zip?download=1 public_dataset.zip
# !unzip -q public_dataset.zip
# !mkdir 'custom_dataset'
# Out:
# --2022-03-04 17:00:52--  https://zenodo.org/record/4048312/files/public_dataset.zip?download=1
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 951442487 (907M) [application/octet-stream]
# Saving to: ‘public_dataset.zip?download=1’
#
# public_dataset.zip? 100%[===================>] 907.37M  2.44MB/s    in 4m 30s
#
# 2022-03-04 17:05:24 (3.36 MB/s) - ‘public_dataset.zip?download=1’ saved [951442487/951442487]

# %%
names   = ['ID','Fever/MP','ORC','STATUS','DIR','DataSet']
join_by = pd.read_csv('/content/Coswara-Data/combined_data.csv')

import glob
df_list = []
for path in tqdm(glob.glob('/content/Coswara-Data/*/*/cough-shallow.wav')):
  temp = pd.DataFrame(columns=['id','DIR'])
  temp['id'] = [path.split('/')[-2]]
  temp['DIR'] = [path]
  temp = pd.merge(left=temp,right=join_by,on='id',how='inner')

  temp['fomp']= (temp['fever']| temp['mp']).apply(int)
  temp['oths']= (temp['cld']|temp['asthma']|temp['cold']|temp['st']|temp['pneumonia']).apply(int)
  temp        = temp[['id','covid_status','DIR','fomp','oths']]
  df_list.append(temp.rename(columns={'id':'ID','covid_status':'STATUS','DIR':'DIR','fomp':'Fever/MP','oths':'ORC'}))
CosData1=pd.concat(df_list)
CosData1['DataSet'] = 'coswara'
CosData1.head()
# Out:
# 100%|██████████| 2745/2745 [00:27<00:00, 99.25it/s]
#                              ID                       STATUS  \
# 0  GlIfVHLGwZejdqrR3MmBcxUBTWi1             under_validation
# 0  cP1Dvsaa6cfAv6mlTjsH8Ezf2i63                positive_mild
# 0  5uJzEx2zAfV2XQ8147WgYYWVeOF3  resp_illness_not_identified
# 0  MwKKn2w3qpcQr260pQXCLbR26WT2               positive_asymp
# 0  rMIXci2Er1OpK4ObuqY15yH4qsv1             under_validation
#
#                                                  DIR  Fever/MP  ORC  DataSet
# 0  /content/Coswara-Data/20220224/GlIfVHLGwZejdqr...         0    0  coswara
# 0  /content/Coswara-Data/20220224/cP1Dvsaa6cfAv6m...         1    1  coswara
# 0  /content/Coswara-Data/20220224/5uJzEx2zAfV2XQ8...         0    1  coswara
# 0  /content/Coswara-Data/20220224/MwKKn2w3qpcQr26...         0    0  coswara
# 0  /content/Coswara-Data/20220224/rMIXci2Er1OpK4O...         0    0  coswara

# %%
CosData1['STATUS'].unique()
# Out:
# array(['under_validation', 'positive_mild', 'resp_illness_not_identified',
#        'positive_asymp', 'recovered_full', 'healthy', 'positive_moderate',
#        'no_resp_illness_exposed'], dtype=object)

# %%
positive_mild = CosData1.loc[CosData1['STATUS']=='positive_mild']
positive_moderate	 = CosData1.loc[CosData1['STATUS']=='positive_moderate']
positive_asymp = CosData1.loc[CosData1['STATUS']=='positive_asymp']

positive = pd.concat([positive_mild,positive_moderate,positive_asymp])

healthy = CosData1.loc[CosData1['STATUS']=='healthy']
resp_illness_not_identified = CosData1.loc[CosData1['STATUS']=='resp_illness_not_identified']
no_resp_illness_exposed = CosData1.loc[CosData1['STATUS']=='no_resp_illness_exposed']
recovered_full = CosData1.loc[CosData1['STATUS']=='recovered_full']

negative =  pd.concat([healthy,resp_illness_not_identified,no_resp_illness_exposed,recovered_full])

print(len(positive))
print(len(negative))

f_negative = negative.loc[negative['STATUS']!='COVID-19'][0:1500]
print(len(f_negative))
# Out:
# 681
# 1983
# 1500

# %%
coughvid  = '/content/public_dataset/'
custpath  = '/content/custom_dataset/' #Where mel spec images will be stored

VidData   = pd.read_csv(os.path.join(coughvid,'metadata_compiled.csv'),header=0)
VidData   = VidData.loc[VidData['cough_detected'] >= 0.9][['uuid','fever_muscle_pain','respiratory_condition','status']]
VidData.dropna(inplace=True)

extradata = VidData.loc[VidData['status']=='COVID-19']
notradata = VidData.loc[VidData['status']!='COVID-19']

TotData   = pd.concat([extradata,notradata],ignore_index= True)
TotData['DIR'] = coughvid + TotData['uuid'] + '.webm'
TotData['DataSet'] = 'coughvid'
TotData['fever_muscle_pain']    = TotData['fever_muscle_pain'].apply(int)
TotData['respiratory_condition']= TotData['respiratory_condition'].apply(int)
## TotData   = pd.concat([CosData,TotData.rename(columns={'uuid':'ID','status':'STATUS','fever_muscle_pain':'Fever/MP','respiratory_condition':'ORC'})])
TotData   = TotData.rename(columns={'uuid':'ID','status':'STATUS','fever_muscle_pain':'Fever/MP','respiratory_condition':'ORC'})
TotData   = TotData.sample(frac=1).reset_index(drop=True)
TotData.head()
# Out:
#                                      ID  Fever/MP  ORC       STATUS  \
# 0  619d3192-2b16-4be4-ba00-fa58d61f7850         0    0      healthy
# 1  68d25e35-8946-474c-88ff-7a452ecc57b8         0    0      healthy
# 2  8094f4ee-3417-4882-af51-9996bebb2140         1    0  symptomatic
# 3  26e4d0d9-a03c-4564-b15e-d8850bb4a2a3         1    0      healthy
# 4  43298143-1004-44ef-889f-10ba9dc9d51f         0    1  symptomatic
#
#                                                  DIR   DataSet
# 0  /content/public_dataset/619d3192-2b16-4be4-ba0...  coughvid
# 1  /content/public_dataset/68d25e35-8946-474c-88f...  coughvid
# 2  /content/public_dataset/8094f4ee-3417-4882-af5...  coughvid
# 3  /content/public_dataset/26e4d0d9-a03c-4564-b15...  coughvid
# 4  /content/public_dataset/43298143-1004-44ef-889...  coughvid

# %%
covid_TotData = TotData[TotData["STATUS"] == "COVID-19" ]
#symptomatic_TotData = TotData[TotData["STATUS"] == "symptomatic" ][:490]
healthy_TotData = TotData[TotData["STATUS"] != "COVID-19" ][:975]

print(len(covid_TotData) , len(healthy_TotData))
covid_TotData.head()
# Out:
# 441 975
#                                       ID  Fever/MP  ORC    STATUS  \
# 19  c85daa1b-6f5b-4bc7-803b-117cb57953e5         0    1  COVID-19
# 23  17e623e8-7179-4805-889b-83ba37063d21         0    0  COVID-19
# 29  a03baece-440f-4026-9705-4fcb2bc9e065         0    0  COVID-19
# 66  5a5dccc2-ce4e-4c4e-ab49-a0dcf6f4a2d0         0    0  COVID-19
# 95  b05935c3-68d7-4a28-aea9-f92fbe295c6c         0    0  COVID-19
#
#                                                   DIR   DataSet
# 19  /content/public_dataset/c85daa1b-6f5b-4bc7-803...  coughvid
# 23  /content/public_dataset/17e623e8-7179-4805-889...  coughvid
# 29  /content/public_dataset/a03baece-440f-4026-970...  coughvid
# 66  /content/public_dataset/5a5dccc2-ce4e-4c4e-ab4...  coughvid
# 95  /content/public_dataset/b05935c3-68d7-4a28-aea...  coughvid

# %%
#!pip install audiomentations
# !pip install audiomentations
# Out:
# Collecting audiomentations
#   Downloading audiomentations-0.22.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 2.8 MB/s
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from audiomentations) (1.21.5)
# Requirement already satisfied: librosa<0.10.0,>0.7.2 in /usr/local/lib/python3.7/dist-packages (from audiomentations) (0.8.1)
# Requirement already satisfied: scipy<2,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from audiomentations) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.0.2)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (4.4.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.51.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.1.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (21.3)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (2.1.9)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa<0.10.0,>0.7.2->audiomentations) (1.6.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa<0.10.0,>0.7.2->audiomentations) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa<0.10.0,>0.7.2->audiomentations) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa<0.10.0,>0.7.2->audiomentations) (3.0.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (1.4.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa<0.10.0,>0.7.2->audiomentations) (3.0.4)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa<0.10.0,>0.7.2->audiomentations) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa<0.10.0,>0.7.2->audiomentations) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa<0.10.0,>0.7.2->audiomentations) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.10.0,>0.7.2->audiomentations) (2.21)
# Installing collected packages: audiomentations
# Successfully installed audiomentations-0.22.0

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import soundfile as sf
import librosa
print(len(covid_TotData))
print(len(positive))
# Out:
# 441
# 681

# %%
augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_fraction=-0.5, max_fraction=0.5, p=0.5),
])

os.makedirs("augmented_data_coswara")

# %%
#os.makedirs("augmented_data_coswara")

xx = pd.DataFrame()

for audio_file in  tqdm(positive["DIR"]):
  #print(audio_file.split("/")[-1] )
  try:
    samples, sr = librosa.load(audio_file)
    augmented_sample = augment(samples=samples, sample_rate=sr)
    sf.write("/content/augmented_data_coswara/" + audio_file.split("/")[-2] + ".wav", augmented_sample, sr) #write with wav extantion

    xx = xx.append(positive.loc[positive['ID'] == audio_file.split("/")[-2]])
    xx["DIR"].replace({ audio_file : "/content/augmented_data_coswara/" + audio_file.split("/")[-2] + ".wav"}, inplace=True)
    xx["ID"].replace({ audio_file.split("/")[-2] :  audio_file.split("/")[-2] + "AUG"}, inplace=True)

  except:
    print("\n File Not Found :))")
# Out:
#  30%|██▉       | 201/681 [01:15<02:18,  3.47it/s]
#  File Not Found :))
#  65%|██████▍   | 440/681 [02:47<01:34,  2.54it/s]
#  File Not Found :))
#  89%|████████▉ | 608/681 [03:49<00:27,  2.64it/s]
#  File Not Found :))
# 100%|██████████| 681/681 [04:17<00:00,  2.64it/s]

# %%
os.makedirs("augmented_data_coughvid")

yy = pd.DataFrame()

for audio_file in  tqdm(covid_TotData["DIR"]):
  #print(audio_file.split("/")[-1] )
  try:
    samples, sr = librosa.load(audio_file)
    augmented_sample = augment(samples=samples, sample_rate=sr)
    sf.write("/content/augmented_data_coughvid/" + audio_file.split("/")[-1][0:-5] + ".wav", augmented_sample, sr) #write with wav extantion

    yy = yy.append(covid_TotData.loc[covid_TotData['ID'] == audio_file.split("/")[-1][0:-5]])
    yy["DIR"].replace({"/content/augmented_data_coughvid/"+ audio_file.split("/")[-1][0:-5] + ".webm": "/content/augmented_data_coughvid/" + audio_file.split("/")[-1][0:-5] + ".wav"}, inplace=True)
    yy["ID"].replace({ audio_file.split("/")[-1][0:-5] :  audio_file.split("/")[-1][0:-5] + "AUG"}, inplace=True)

  except:
    print("\n File Not Found :))")
# Out:
#   0%|          | 0/441 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 1/441 [00:01<12:24,  1.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 2/441 [00:02<09:43,  1.33s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 3/441 [00:03<08:49,  1.21s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 4/441 [00:04<07:21,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 5/441 [00:05<07:30,  1.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 6/441 [00:06<06:40,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 7/441 [00:07<07:14,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 8/441 [00:08<06:34,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 9/441 [00:08<04:50,  1.49it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  File Not Found :))
#   2%|▏         | 10/441 [00:09<05:49,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 11/441 [00:10<06:30,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 12/441 [00:11<06:20,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 13/441 [00:12<06:22,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 14/441 [00:13<06:17,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 15/441 [00:14<06:08,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 16/441 [00:14<06:05,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 17/441 [00:15<05:16,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 18/441 [00:16<06:04,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 19/441 [00:17<06:27,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 20/441 [00:18<06:39,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 21/441 [00:19<06:05,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 22/441 [00:19<05:06,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 23/441 [00:20<05:20,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 24/441 [00:21<04:54,  1.42it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 25/441 [00:22<05:38,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 26/441 [00:23<06:25,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 27/441 [00:24<06:13,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▋         | 28/441 [00:25<06:12,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 29/441 [00:26<06:35,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 30/441 [00:27<06:18,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 31/441 [00:28<06:50,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 32/441 [00:29<06:52,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 33/441 [00:30<06:57,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 34/441 [00:31<06:30,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 35/441 [00:32<06:40,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 36/441 [00:33<07:02,  1.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 37/441 [00:34<07:03,  1.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▊         | 38/441 [00:35<07:15,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 39/441 [00:36<06:33,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 40/441 [00:37<06:45,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 41/441 [00:38<06:11,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 42/441 [00:38<05:23,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 43/441 [00:39<05:27,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 44/441 [00:40<05:32,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 45/441 [00:41<06:05,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 46/441 [00:42<06:34,  1.00it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 47/441 [00:43<06:00,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 48/441 [00:43<05:00,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 49/441 [00:44<04:53,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█▏        | 50/441 [00:45<04:44,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 51/441 [00:45<04:04,  1.59it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 52/441 [00:46<05:10,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 53/441 [00:47<05:40,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 54/441 [00:48<05:33,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 55/441 [00:49<05:31,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 56/441 [00:50<05:01,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 57/441 [00:50<04:20,  1.47it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 58/441 [00:51<04:24,  1.45it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 59/441 [00:51<03:49,  1.67it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▎        | 60/441 [00:52<04:43,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 61/441 [00:53<04:52,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 62/441 [00:54<05:02,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 63/441 [00:55<05:03,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 64/441 [00:55<04:53,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 65/441 [00:57<05:25,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 66/441 [00:57<05:08,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 67/441 [00:58<04:54,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 68/441 [00:59<04:44,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 69/441 [01:00<04:53,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 70/441 [01:00<04:22,  1.41it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 71/441 [01:01<04:24,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▋        | 72/441 [01:02<04:39,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 73/441 [01:02<04:44,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 74/441 [01:03<04:30,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 75/441 [01:04<05:06,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 76/441 [01:05<05:38,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 77/441 [01:06<05:52,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 78/441 [01:07<05:59,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 79/441 [01:08<05:28,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 80/441 [01:09<05:56,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 81/441 [01:10<05:24,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▊        | 82/441 [01:11<06:28,  1.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 83/441 [01:12<06:01,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 84/441 [01:13<05:41,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 85/441 [01:14<05:50,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 86/441 [01:15<04:55,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 87/441 [01:16<05:14,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 88/441 [01:17<05:32,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 89/441 [01:18<05:07,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 90/441 [01:18<04:50,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 91/441 [01:19<04:49,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 92/441 [01:20<04:14,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 93/441 [01:20<03:51,  1.50it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██▏       | 94/441 [01:21<03:37,  1.60it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 95/441 [01:21<03:46,  1.53it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 96/441 [01:22<04:24,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 97/441 [01:23<05:01,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 98/441 [01:25<05:24,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 99/441 [01:25<05:10,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 100/441 [01:26<04:39,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 101/441 [01:27<04:29,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 102/441 [01:27<04:09,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 103/441 [01:28<04:27,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▎       | 104/441 [01:29<04:19,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 105/441 [01:30<04:13,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 106/441 [01:30<03:36,  1.55it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 107/441 [01:31<04:01,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 108/441 [01:32<04:11,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 109/441 [01:33<04:45,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 110/441 [01:34<04:37,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 111/441 [01:35<04:57,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 112/441 [01:35<04:21,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 113/441 [01:36<04:11,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 114/441 [01:37<04:43,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 115/441 [01:37<03:50,  1.41it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▋       | 116/441 [01:38<03:55,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 117/441 [01:39<04:36,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 118/441 [01:40<04:24,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 119/441 [01:41<04:06,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 120/441 [01:41<03:57,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 121/441 [01:42<04:08,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 122/441 [01:43<03:54,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 123/441 [01:44<04:00,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 124/441 [01:44<03:22,  1.56it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 125/441 [01:45<03:29,  1.51it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▊       | 126/441 [01:46<03:44,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 127/441 [01:46<03:45,  1.39it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 128/441 [01:47<03:22,  1.54it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 129/441 [01:48<03:28,  1.50it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 130/441 [01:49<04:04,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 131/441 [01:50<04:42,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 132/441 [01:51<04:24,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 133/441 [01:51<04:16,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 134/441 [01:52<04:05,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 135/441 [01:53<04:34,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 136/441 [01:54<04:48,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 137/441 [01:55<04:59,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███▏      | 138/441 [01:56<04:33,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 139/441 [01:57<04:56,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 140/441 [01:58<04:11,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 141/441 [01:59<04:28,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 142/441 [02:00<04:48,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 143/441 [02:00<04:14,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 144/441 [02:01<03:56,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 145/441 [02:02<04:17,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 146/441 [02:03<04:13,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 147/441 [02:04<04:10,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▎      | 148/441 [02:04<03:39,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 149/441 [02:05<03:44,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 150/441 [02:06<03:47,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 151/441 [02:07<03:43,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 152/441 [02:08<04:07,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 153/441 [02:08<03:45,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 154/441 [02:10<04:17,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 155/441 [02:11<04:28,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 156/441 [02:11<04:09,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 157/441 [02:12<03:51,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 158/441 [02:13<03:24,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 159/441 [02:13<03:32,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▋      | 160/441 [02:14<03:29,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 161/441 [02:14<03:02,  1.53it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 162/441 [02:15<02:46,  1.68it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 163/441 [02:15<02:31,  1.83it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 164/441 [02:16<02:45,  1.68it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 165/441 [02:16<02:26,  1.88it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 166/441 [02:17<02:42,  1.70it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 167/441 [02:18<02:50,  1.61it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 168/441 [02:19<03:10,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 169/441 [02:20<03:20,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 170/441 [02:21<03:46,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 171/441 [02:21<03:37,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 172/441 [02:22<03:53,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 173/441 [02:23<04:06,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 174/441 [02:24<03:27,  1.29it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|███▉      | 175/441 [02:25<03:30,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|███▉      | 176/441 [02:26<03:52,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|████      | 177/441 [02:27<03:37,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  40%|████      | 178/441 [02:27<03:02,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████      | 179/441 [02:28<03:13,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████      | 180/441 [02:29<03:19,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████      | 181/441 [02:29<03:23,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████▏     | 182/441 [02:30<03:48,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  41%|████▏     | 183/441 [02:31<03:12,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 184/441 [02:32<03:34,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 185/441 [02:33<03:14,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 186/441 [02:33<03:10,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  42%|████▏     | 187/441 [02:34<03:07,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 188/441 [02:35<02:53,  1.46it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 189/441 [02:36<03:28,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 190/441 [02:36<03:19,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  43%|████▎     | 191/441 [02:37<03:36,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▎     | 192/441 [02:38<03:23,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 193/441 [02:39<03:13,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 194/441 [02:40<03:31,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 195/441 [02:41<03:41,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  44%|████▍     | 196/441 [02:42<03:50,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▍     | 197/441 [02:43<03:42,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▍     | 198/441 [02:43<03:26,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▌     | 199/441 [02:44<03:12,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  45%|████▌     | 200/441 [02:45<02:58,  1.35it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ...
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  85%|████████▌ | 375/441 [05:12<01:02,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  85%|████████▌ | 376/441 [05:12<00:50,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  85%|████████▌ | 377/441 [05:13<00:48,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▌ | 378/441 [05:13<00:43,  1.45it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▌ | 379/441 [05:14<00:43,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▌ | 380/441 [05:15<00:48,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  86%|████████▋ | 381/441 [05:16<00:47,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 382/441 [05:17<00:51,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 383/441 [05:18<00:47,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 384/441 [05:19<00:52,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  87%|████████▋ | 385/441 [05:20<00:49,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 386/441 [05:20<00:46,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 387/441 [05:21<00:43,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 388/441 [05:22<00:48,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 389/441 [05:23<00:44,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  88%|████████▊ | 390/441 [05:24<00:46,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▊ | 391/441 [05:24<00:39,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▉ | 392/441 [05:26<00:44,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▉ | 393/441 [05:27<00:45,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  89%|████████▉ | 394/441 [05:28<00:48,  1.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|████████▉ | 395/441 [05:29<00:43,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|████████▉ | 396/441 [05:29<00:38,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|█████████ | 397/441 [05:30<00:33,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|█████████ | 398/441 [05:31<00:32,  1.34it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  90%|█████████ | 399/441 [05:32<00:34,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████ | 400/441 [05:32<00:29,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████ | 401/441 [05:33<00:30,  1.32it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████ | 402/441 [05:33<00:27,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  91%|█████████▏| 403/441 [05:34<00:27,  1.37it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 404/441 [05:35<00:26,  1.38it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 405/441 [05:36<00:24,  1.45it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 406/441 [05:37<00:27,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  92%|█████████▏| 407/441 [05:37<00:25,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 408/441 [05:38<00:26,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 409/441 [05:39<00:28,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 410/441 [05:40<00:29,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 411/441 [05:41<00:29,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  93%|█████████▎| 412/441 [05:42<00:27,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▎| 413/441 [05:43<00:27,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▍| 414/441 [05:44<00:23,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▍| 415/441 [05:45<00:22,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  94%|█████████▍| 416/441 [05:46<00:23,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▍| 417/441 [05:47<00:23,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▍| 418/441 [05:47<00:19,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▌| 419/441 [05:49<00:19,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▌| 420/441 [05:49<00:15,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  95%|█████████▌| 421/441 [05:49<00:11,  1.76it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  File Not Found :))
#  96%|█████████▌| 422/441 [05:50<00:12,  1.55it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▌| 423/441 [05:51<00:14,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▌| 424/441 [05:52<00:13,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  96%|█████████▋| 425/441 [05:53<00:12,  1.31it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 426/441 [05:53<00:11,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 427/441 [05:54<00:09,  1.44it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 428/441 [05:55<00:10,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  97%|█████████▋| 429/441 [05:56<00:10,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 430/441 [05:57<00:10,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 431/441 [05:58<00:10,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 432/441 [05:59<00:08,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 433/441 [06:00<00:07,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  98%|█████████▊| 434/441 [06:01<00:06,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▊| 435/441 [06:01<00:04,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▉| 436/441 [06:02<00:04,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▉| 437/441 [06:03<00:03,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  99%|█████████▉| 438/441 [06:04<00:02,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 100%|█████████▉| 439/441 [06:05<00:01,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 100%|█████████▉| 440/441 [06:06<00:00,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# 100%|██████████| 441/441 [06:06<00:00,  1.20it/s]

# %%
covid_TotData.head()
# Out:
#                                         ID  ...   DataSet
# 1312  0c35e382-31cd-42cb-bc87-8a84b9c52a41  ...  coughvid
# 4360  65e99746-4a0c-4496-8cb0-e234ed1fa93b  ...  coughvid
# 2411  42dcff9d-b2e1-4b9e-bd93-81a0a100d232  ...  coughvid
# 5317  20602da6-a92f-40ad-81d2-1688f5f1fcde  ...  coughvid
# 1505  a08d28dc-9b8d-43ae-a864-9f25be0e1718  ...  coughvid
#
# [5 rows x 6 columns]

# %%
healthy_TotData.head()
# Out:
#                                         ID  ...   DataSet
# 1039  3f60d2a0-aed6-45d0-b0f7-81bcf743a4e7  ...  coughvid
# 783   651341cb-6be7-4981-b3e0-a454dee3af64  ...  coughvid
# 961   d7de9778-2a75-4e0e-accf-366b20cd1969  ...  coughvid
# 168   c6f5b4e5-c1b9-4cab-a860-ae76a09acfdf  ...  coughvid
# 219   e54b052a-2849-461f-b490-55288275abfa  ...  coughvid
#
# [5 rows x 6 columns]

# %%
yy.head()
# Out:
#                                            ID  ...   DataSet
# 1645  15f12b8d-7ba5-444e-975f-f1b26c6e75aeAUG  ...  coughvid
# 1760  bcb56997-8193-4fbb-9b15-8fcaa5fba53bAUG  ...  coughvid
# 2340  1a324acb-12f7-4eef-8e8c-0c71a47280e2AUG  ...  coughvid
# 3531  46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664AUG  ...  coughvid
# 2294  178f39e2-a261-4ec6-a8fb-3f89c3c795bbAUG  ...  coughvid
#
# [5 rows x 6 columns]

# %%
xx.head()
# Out:
#                                 ID             STATUS  ... ORC  DataSet
# 0  nqLItJsNy8hMMv0uzVGitvRIC3U2AUG      positive_mild  ...   0  coswara
# 0  BZHvK60v1LY9cBfLvYkBkJxdfNz2AUG      positive_mild  ...   1  coswara
# 0  D9EEvq1ksqN6PEWzIAy7Mu5e8jJ3AUG  positive_moderate  ...   1  coswara
# 0  dIDHgSBqirYuRJOWvx2370BITLk1AUG      positive_mild  ...   1  coswara
# 0  373AihVhKDYxeUR24zNi11JavqC3AUG  positive_moderate  ...   1  coswara
#
# [5 rows x 6 columns]

# %%
positive.head()
# Out:
#                              ID             STATUS  ... ORC  DataSet
# 0  BVDJ00JbBEeF6oAOYJzebbGLlGY2      positive_mild  ...   1  coswara
# 0  AutXsDVtEcVH9ZQ58NqDunDcqZv1      positive_mild  ...   1  coswara
# 0  yTldbEFYIkOvoaY6f0elulpdzxQ2     positive_asymp  ...   0  coswara
# 0  0Js6ZUZQ9NUnu568Fh7B6mZ1R8o1  positive_moderate  ...   0  coswara
# 0  C0GYeEOzbUXPzOObgkf0wuyJxur1      positive_mild  ...   1  coswara
#
# [5 rows x 6 columns]

# %%
f_negative.head()
# Out:
#                              ID   STATUS  ... ORC  DataSet
# 0  HSj0b9JLMjVfqxpQi1s6OVQXkZw1  healthy  ...   0  coswara
# 0  TRK6gUseEUS7dbF0soG80W1uLm53  healthy  ...   0  coswara
# 0  DycfRd7vyobY2PgwT3rQOemSbP53  healthy  ...   0  coswara
# 0  VFG4CURiubQsHbGiux3co3TyL043  healthy  ...   0  coswara
# 0  cUmQfhZCLYML6b9ETc7qJAKXv1G3  healthy  ...   0  coswara
#
# [5 rows x 6 columns]

# %%
covid_TotData = covid_TotData.sample(frac = 1)
healthy_TotData = healthy_TotData.sample(frac = 1)
yy = yy.sample(frac = 1)
xx =xx.sample(frac = 1)
positive = positive.sample(frac = 1)
f_negative = f_negative.sample(frac = 1)

# %%
covid_TotData_train = covid_TotData[:int(0.7*len(covid_TotData))]   # split 80, 10, 10
covid_TotData_test = covid_TotData[ int(0.7*len(covid_TotData)): int(0.9*len(covid_TotData))]    #covid_TotData = 441 ... 308,66,67
covid_TotData_val = covid_TotData[ int(0.9*len(covid_TotData)) :]


healthy_TotData_train = healthy_TotData[:int(0.8*len(healthy_TotData))]   #covid_TotData = 975 ... 682,147,146
healthy_TotData_test = healthy_TotData[ int(0.8*len(healthy_TotData)): int(0.9*len(healthy_TotData))]
healthy_TotData_val = healthy_TotData[ int(0.9*len(healthy_TotData)) :]

aug_covid_samples_train = yy[:int(0.9*len(yy))]   #yy = 434
#aug_covid_samples_test = yy[ int(0.8*len(yy)): int(0.9*len(yy))]
aug_covid_samples_val = yy[ int(0.9*len(yy)) :]



aug_positive_samples_train = xx[:int(0.9*len(xx))]   #xx = 681
#aug_positive_samples_test = xx[ int(0.8*len(xx)): int(0.9*len(xx))]
aug_positive_samples_val = xx[ int(0.9*len(xx)) :]



positive_samples_train = positive[:int(0.7*len(positive))]    #positive = 678
positive_samples_test = positive[ int(0.7*len(positive)): int(0.9*len(positive))]
positive_samples_val = positive[ int(0.9*len(positive)) :]


negative_samples_train = f_negative[:int(0.8*len(f_negative))]    #f_negative = 1200
negative_samples_test = f_negative[ int(0.8*len(f_negative)): int(0.9*len(f_negative))]
negattive_samples_val = f_negative[ int(0.9*len(f_negative)) :]

# %%
print(len(covid_TotData_train),len(healthy_TotData_train),len(aug_covid_samples_train),len(aug_positive_samples_train),len(positive_samples_train),len(negative_samples_train))
print(len(covid_TotData_val),  len(healthy_TotData_val),  len(aug_covid_samples_val),  len(aug_positive_samples_val),  len(positive_samples_val),  len(negattive_samples_val))
#print(len(covid_TotData_test), len(healthy_TotData_test), len(aug_covid_samples_test), len(aug_positive_samples_test), len(positive_samples_test), len(negative_samples_test))
print(len(covid_TotData_test), len(healthy_TotData_test), len(positive_samples_test), len(negative_samples_test))
# Out:
# 308 780 390 610 476 1200
# 45 98 44 68 69 150
# 88 97 136 150

# %%
#train Data
frame1 = [covid_TotData_train,healthy_TotData_train,aug_covid_samples_train,aug_positive_samples_train,positive_samples_train,negative_samples_train]
Data_train = pd.concat(frame1)


# validation Data
frame2 = [covid_TotData_val,healthy_TotData_val,aug_covid_samples_val,aug_positive_samples_val,positive_samples_val,negattive_samples_val
]
Data_val = pd.concat(frame2)

# test Data
#frame3 = [covid_TotData_test,healthy_TotData_test,aug_covid_samples_test,aug_positive_samples_test,positive_samples_test,negative_samples_test]
frame3 = [covid_TotData_test,healthy_TotData_test,positive_samples_test,negative_samples_test]
Data_test = pd.concat(frame3)
print(len(Data_train) , len(Data_val) , len(Data_test))
# Out:
# 3764 474 471

# %%
def feature_extractor(row):

  name     = row[-6]
  try:
    audio,sr = librosa.load(row[-2])
    #For MFCCS 
    mfccs    = librosa.feature.mfcc(y=audio,sr=22050, n_mfcc=39)
    mfccsscaled = np.mean(mfccs.T,axis=0)
    
    #Mel Spectogram
    pylab.axis('off') # no axis
    pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[])
    melspec  = librosa.feature.melspectrogram(y=audio,sr=sr)
    s_db     = librosa.power_to_db(melspec, ref=np.max)
    librosa.display.specshow(s_db)

    savepath = os.path.join(custpath,name+'.png')
    pylab.savefig(savepath, bbox_inches=None, pad_inches=0)
    pylab.close()
  except:
    print('File cannot open')
    return None,None
   # return mfccsscaled

  return mfccsscaled,savepath

# %%
#train
features_train = []
diagnoses_train= []
imgpaths_train = []
#validation
features_val = []
diagnoses_val= []
imgpaths_val = []
#test
features_test = []
diagnoses_test= []
imgpaths_test = []

# %%
# train
for row in tqdm(Data_train.values):
  mfccs,savepath  = feature_extractor(row)
  features_train.append(mfccs)
  imgpaths_train.append(savepath)
  diagnoses_train.append([row[-5],row[-4]])
# Out:
#   0%|          | 0/3764 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 1/3764 [00:00<1:00:45,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 2/3764 [00:01<59:33,  1.05it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 3/3764 [00:02<36:21,  1.72it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# File cannot open
#   0%|          | 4/3764 [00:02<44:50,  1.40it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 5/3764 [00:03<49:26,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 6/3764 [00:04<52:36,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 7/3764 [00:05<54:19,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 8/3764 [00:06<55:50,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 9/3764 [00:07<54:31,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 10/3764 [00:08<55:27,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 11/3764 [00:09<56:24,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 12/3764 [00:10<59:53,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 13/3764 [00:11<59:16,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 14/3764 [00:12<53:51,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 15/3764 [00:12<55:01,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 16/3764 [00:13<55:43,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 17/3764 [00:14<49:17,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 18/3764 [00:15<51:37,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 19/3764 [00:16<53:26,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 20/3764 [00:17<54:51,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 21/3764 [00:18<55:59,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 22/3764 [00:19<56:43,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 23/3764 [00:19<51:53,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 24/3764 [00:20<52:34,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 25/3764 [00:21<54:16,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 26/3764 [00:22<51:12,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 27/3764 [00:22<45:44,  1.36it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 28/3764 [00:23<49:50,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 29/3764 [00:24<49:00,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 30/3764 [00:25<51:53,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 31/3764 [00:26<53:16,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 32/3764 [00:27<54:46,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 33/3764 [00:28<55:46,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 34/3764 [00:28<49:20,  1.26it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 35/3764 [00:29<52:09,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 36/3764 [00:30<55:08,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 37/3764 [00:30<42:53,  1.45it/s]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 38/3764 [00:32<50:25,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 39/3764 [00:33<55:57,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 40/3764 [00:33<50:19,  1.23it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 41/3764 [00:34<52:49,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 42/3764 [00:35<54:34,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 43/3764 [00:36<48:20,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 44/3764 [00:37<51:29,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 45/3764 [00:38<53:38,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 46/3764 [00:39<55:14,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 47/3764 [00:40<56:29,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 48/3764 [00:40<57:21,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 49/3764 [00:41<57:53,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 50/3764 [00:42<58:07,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 51/3764 [00:43<57:56,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 52/3764 [00:44<58:16,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 53/3764 [00:45<58:24,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 54/3764 [00:46<1:03:57,  1.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 55/3764 [00:47<1:02:32,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 56/3764 [00:48<1:01:13,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 57/3764 [00:49<1:00:28,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 58/3764 [00:50<59:58,  1.03it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 59/3764 [00:51<51:13,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 60/3764 [00:51<47:39,  1.30it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 61/3764 [00:52<50:55,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 62/3764 [00:53<53:26,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 63/3764 [00:54<52:37,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 64/3764 [00:55<54:26,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 65/3764 [00:56<55:23,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 66/3764 [00:57<56:27,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 67/3764 [00:58<57:17,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 68/3764 [00:59<56:15,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 69/3764 [01:00<57:02,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 70/3764 [01:01<57:34,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 71/3764 [01:01<53:28,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 72/3764 [01:02<51:04,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 73/3764 [01:03<48:20,  1.27it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 74/3764 [01:04<51:50,  1.19it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 75/3764 [01:05<54:06,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 76/3764 [01:06<55:50,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 77/3764 [01:06<52:04,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 78/3764 [01:07<50:26,  1.22it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 79/3764 [01:08<53:06,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 80/3764 [01:09<49:20,  1.24it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 81/3764 [01:10<49:07,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 82/3764 [01:11<52:16,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 83/3764 [01:12<54:15,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 84/3764 [01:13<55:46,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 85/3764 [01:14<56:57,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 86/3764 [01:14<57:21,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 87/3764 [01:15<58:00,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 88/3764 [01:16<53:35,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 89/3764 [01:17<55:10,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 90/3764 [01:18<50:50,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 91/3764 [01:19<53:30,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 92/3764 [01:20<55:15,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 93/3764 [01:21<53:14,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 94/3764 [01:21<55:03,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 95/3764 [01:22<55:47,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 96/3764 [01:23<57:10,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 97/3764 [01:24<58:18,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 98/3764 [01:25<53:46,  1.14it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 99/3764 [01:26<51:53,  1.18it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 100/3764 [01:27<54:46,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 101/3764 [01:28<56:02,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 102/3764 [01:29<57:02,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 103/3764 [01:30<58:00,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 104/3764 [01:31<55:06,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 105/3764 [01:31<52:20,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 106/3764 [01:33<59:28,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 107/3764 [01:33<55:23,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 108/3764 [01:34<57:11,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 109/3764 [01:35<58:08,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 110/3764 [01:36<58:25,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 111/3764 [01:37<59:03,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 112/3764 [01:38<59:38,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 113/3764 [01:39<58:01,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 114/3764 [01:40<52:52,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 115/3764 [01:41<55:00,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 116/3764 [01:42<56:28,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 117/3764 [01:43<57:47,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 118/3764 [01:44<52:35,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 119/3764 [01:45<55:12,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 120/3764 [01:45<54:01,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 121/3764 [01:46<55:58,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 122/3764 [01:47<57:15,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 123/3764 [01:48<50:11,  1.21it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 124/3764 [01:49<53:32,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 125/3764 [01:50<48:34,  1.25it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 126/3764 [01:51<52:01,  1.17it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 127/3764 [01:52<54:40,  1.11it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 128/3764 [01:52<50:23,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 129/3764 [01:53<47:30,  1.28it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 130/3764 [01:54<45:30,  1.33it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 131/3764 [01:55<50:21,  1.20it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 132/3764 [01:56<53:30,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 133/3764 [01:57<55:36,  1.09it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 134/3764 [01:58<56:58,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 135/3764 [01:59<58:25,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 136/3764 [01:59<53:32,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 137/3764 [02:00<56:00,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 138/3764 [02:01<57:48,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 139/3764 [02:02<58:45,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 140/3764 [02:03<59:13,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 141/3764 [02:04<52:32,  1.15it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 142/3764 [02:05<53:34,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 143/3764 [02:06<54:45,  1.10it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 144/3764 [02:07<56:38,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 145/3764 [02:08<57:51,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 146/3764 [02:09<59:27,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 147/3764 [02:10<59:36,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 148/3764 [02:11<1:00:18,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 149/3764 [02:12<1:00:50,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 150/3764 [02:13<1:01:11,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 151/3764 [02:14<1:01:23,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 152/3764 [02:15<1:01:12,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 153/3764 [02:16<1:01:33,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 154/3764 [02:17<56:04,  1.07it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 155/3764 [02:18<57:24,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 156/3764 [02:19<53:30,  1.12it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 157/3764 [02:20<55:58,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 158/3764 [02:21<57:40,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 159/3764 [02:22<58:50,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 160/3764 [02:23<59:27,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 161/3764 [02:24<1:00:11,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 162/3764 [02:25<1:00:37,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 163/3764 [02:25<54:10,  1.11it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 164/3764 [02:26<56:40,  1.06it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 165/3764 [02:27<58:12,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 166/3764 [02:29<59:23,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 167/3764 [02:29<55:27,  1.08it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 168/3764 [02:30<57:45,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 169/3764 [02:31<53:10,  1.13it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 170/3764 [02:32<56:03,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 171/3764 [02:32<43:26,  1.38it/s]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 172/3764 [02:34<56:58,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 173/3764 [02:35<58:30,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 174/3764 [02:36<59:25,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 175/3764 [02:37<1:00:01,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 176/3764 [02:38<57:56,  1.03it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 177/3764 [02:39<59:19,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 178/3764 [02:40<1:00:16,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 179/3764 [02:41<58:30,  1.02it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 180/3764 [02:42<59:29,  1.00it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 181/3764 [02:43<55:56,  1.07it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 182/3764 [02:44<58:00,  1.03it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 183/3764 [02:45<58:53,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 184/3764 [02:46<59:59,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 185/3764 [02:47<1:00:52,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 186/3764 [02:48<1:01:07,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 187/3764 [02:49<55:20,  1.08it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 188/3764 [02:50<57:31,  1.04it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 189/3764 [02:51<58:45,  1.01it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 190/3764 [02:52<1:00:05,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 191/3764 [02:52<54:10,  1.10it/s]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 192/3764 [02:53<56:44,  1.05it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 193/3764 [02:54<58:27,  1.02it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 194/3764 [02:56<59:37,  1.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 195/3764 [02:57<59:54,  1.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 196/3764 [02:58<1:00:49,  1.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 197/3764 [02:59<59:34,  1.00s/it]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 198/3764 [02:59<46:04,  1.29it/s]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 199/3764 [03:00<51:21,  1.16it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
# ...
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1420/3764 [30:03<1:09:48,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1421/3764 [30:04<1:06:55,  1.71s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1422/3764 [30:06<1:08:06,  1.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1423/3764 [30:08<1:08:50,  1.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1424/3764 [30:10<1:07:08,  1.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1425/3764 [30:11<1:08:10,  1.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1426/3764 [30:13<1:04:45,  1.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1427/3764 [30:14<1:00:05,  1.54s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1428/3764 [30:16<1:02:33,  1.61s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1429/3764 [30:18<1:05:05,  1.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1430/3764 [30:20<1:06:46,  1.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1431/3764 [30:21<1:07:38,  1.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1432/3764 [30:23<1:03:24,  1.63s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1433/3764 [30:25<1:05:40,  1.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1434/3764 [30:26<1:07:03,  1.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1435/3764 [30:28<1:07:51,  1.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1436/3764 [30:30<1:08:38,  1.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1437/3764 [30:32<1:09:22,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1438/3764 [30:34<1:09:36,  1.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1439/3764 [30:35<1:06:37,  1.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1440/3764 [30:37<1:04:24,  1.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1441/3764 [30:38<1:06:06,  1.71s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1442/3764 [30:40<1:03:54,  1.65s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1443/3764 [30:42<1:05:39,  1.70s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1444/3764 [30:44<1:06:42,  1.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1445/3764 [30:45<1:04:28,  1.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1446/3764 [30:47<1:02:18,  1.61s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1447/3764 [30:48<1:02:15,  1.61s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1448/3764 [30:50<1:02:07,  1.61s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 1449/3764 [30:51<59:44,  1.55s/it]  /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1450/3764 [30:53<1:02:31,  1.62s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1451/3764 [30:54<1:00:40,  1.57s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1452/3764 [30:56<1:03:15,  1.64s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1453/3764 [30:58<1:04:57,  1.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1454/3764 [31:00<1:06:20,  1.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1455/3764 [31:02<1:07:26,  1.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1456/3764 [31:04<1:08:20,  1.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1457/3764 [31:05<1:08:53,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 1458/3764 [31:07<1:09:23,  1.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1459/3764 [31:09<1:09:59,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1460/3764 [31:11<1:07:03,  1.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1461/3764 [31:12<1:05:44,  1.71s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1462/3764 [31:14<1:06:46,  1.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1463/3764 [31:16<1:07:39,  1.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1464/3764 [31:18<1:08:26,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1465/3764 [31:20<1:08:47,  1.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1466/3764 [31:21<1:08:58,  1.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1467/3764 [31:23<1:09:00,  1.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1468/3764 [31:25<1:09:21,  1.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1469/3764 [31:27<1:08:15,  1.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1470/3764 [31:29<1:08:31,  1.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1471/3764 [31:30<1:08:56,  1.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1472/3764 [31:32<1:09:18,  1.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1473/3764 [31:34<1:09:35,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1474/3764 [31:36<1:09:37,  1.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1475/3764 [31:38<1:09:51,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1476/3764 [31:40<1:09:54,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 1477/3764 [31:41<1:09:54,  1.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  61%|██████    | 2305/3764 [35:14<10:23,  2.34it/s]
# File cannot open
#  69%|██████▊   | 2586/3764 [37:13<10:04,  1.95it/s]
# File cannot open
#  69%|██████▉   | 2592/3764 [37:16<08:56,  2.18it/s]
# File cannot open
#  70%|██████▉   | 2629/3764 [37:33<07:31,  2.51it/s]
# File cannot open
#  70%|███████   | 2641/3764 [37:38<09:44,  1.92it/s]
# File cannot open
#  72%|███████▏  | 2704/3764 [38:07<07:40,  2.30it/s]
# File cannot open
#  73%|███████▎  | 2743/3764 [38:23<05:31,  3.08it/s]
# File cannot open
#  76%|███████▌  | 2849/3764 [39:10<07:14,  2.10it/s]
# File cannot open
#  76%|███████▌  | 2863/3764 [39:16<07:03,  2.13it/s]
# File cannot open
#  77%|███████▋  | 2893/3764 [39:33<05:54,  2.45it/s]
# File cannot open
#  78%|███████▊  | 2933/3764 [39:51<06:37,  2.09it/s]
# File cannot open
#  78%|███████▊  | 2946/3764 [39:57<06:04,  2.24it/s]
# File cannot open
#  82%|████████▏ | 3092/3764 [40:59<03:52,  2.89it/s]
# File cannot open
#  82%|████████▏ | 3101/3764 [41:02<04:57,  2.23it/s]
# File cannot open
#  83%|████████▎ | 3115/3764 [41:07<03:41,  2.94it/s]
# File cannot open
#  83%|████████▎ | 3129/3764 [41:14<04:40,  2.26it/s]
# File cannot open
#  84%|████████▎ | 3144/3764 [41:19<04:03,  2.55it/s]
# File cannot open
#  84%|████████▍ | 3176/3764 [41:32<03:57,  2.48it/s]
# File cannot open
#  85%|████████▍ | 3193/3764 [41:39<04:43,  2.02it/s]
# File cannot open
#  88%|████████▊ | 3325/3764 [42:35<03:26,  2.13it/s]
# File cannot open
#  90%|████████▉ | 3383/3764 [43:01<02:47,  2.28it/s]
# File cannot open
#  93%|█████████▎| 3504/3764 [43:56<02:21,  1.83it/s]
# File cannot open
#  94%|█████████▍| 3554/3764 [44:19<01:49,  1.92it/s]
# File cannot open
#  96%|█████████▌| 3599/3764 [44:37<01:03,  2.59it/s]
# File cannot open
# 100%|██████████| 3764/3764 [45:58<00:00,  1.36it/s]

# %%
#validation
for row in tqdm(Data_val.values):
  mfccs,savepath  = feature_extractor(row)
  features_val.append(mfccs)
  imgpaths_val.append(savepath)
  diagnoses_val.append([row[-5],row[-4]])
# Out:
#   0%|          | 0/474 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 1/474 [00:02<20:59,  2.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 2/474 [00:05<21:45,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 3/474 [00:08<20:57,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 4/474 [00:10<21:19,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 5/474 [00:13<21:27,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 6/474 [00:16<21:36,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 7/474 [00:19<21:39,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 8/474 [00:22<21:34,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 9/474 [00:24<21:38,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 10/474 [00:27<21:39,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 11/474 [00:30<21:14,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 12/474 [00:33<21:19,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 13/474 [00:34<18:39,  2.43s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 14/474 [00:37<19:31,  2.55s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 15/474 [00:40<20:05,  2.63s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 16/474 [00:43<20:24,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 17/474 [00:46<20:42,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 18/474 [00:48<20:56,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 19/474 [00:51<19:44,  2.60s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 20/474 [00:53<20:12,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 21/474 [00:56<19:45,  2.62s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 22/474 [00:59<20:11,  2.68s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 23/474 [01:01<19:34,  2.60s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 24/474 [01:04<19:59,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 25/474 [01:06<19:17,  2.58s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 26/474 [01:09<19:47,  2.65s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 27/474 [01:12<20:03,  2.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 28/474 [01:15<20:15,  2.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 29/474 [01:16<17:48,  2.40s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▋         | 30/474 [01:19<18:44,  2.53s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 31/474 [01:22<19:17,  2.61s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 32/474 [01:25<19:37,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 33/474 [01:28<19:56,  2.71s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 34/474 [01:30<20:05,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 35/474 [01:33<20:12,  2.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 36/474 [01:36<20:16,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 37/474 [01:39<20:14,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 38/474 [01:42<20:16,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 39/474 [01:45<20:20,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 40/474 [01:47<19:13,  2.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▊         | 41/474 [01:50<19:30,  2.70s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 42/474 [01:52<19:43,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 43/474 [01:55<19:49,  2.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 44/474 [01:58<19:52,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 45/474 [02:01<19:55,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 46/474 [02:03<19:17,  2.70s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 47/474 [02:06<19:08,  2.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 48/474 [02:09<19:28,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 49/474 [02:12<19:36,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 50/474 [02:15<19:43,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 51/474 [02:17<19:41,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 52/474 [02:20<19:43,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 53/474 [02:23<19:41,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█▏        | 54/474 [02:26<19:41,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 55/474 [02:29<19:35,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 56/474 [02:31<18:57,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 57/474 [02:34<18:35,  2.68s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 58/474 [02:37<18:55,  2.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 59/474 [02:39<18:40,  2.70s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 60/474 [02:42<18:08,  2.63s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 61/474 [02:45<18:23,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 62/474 [02:46<16:16,  2.37s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 63/474 [02:49<17:09,  2.51s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▎        | 64/474 [02:52<17:48,  2.61s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▎        | 65/474 [02:55<18:14,  2.68s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 66/474 [02:58<18:33,  2.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 67/474 [03:00<18:46,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 68/474 [03:03<18:35,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 69/474 [03:05<16:20,  2.42s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 70/474 [03:08<17:10,  2.55s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 71/474 [03:10<17:17,  2.57s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 72/474 [03:13<17:47,  2.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 73/474 [03:16<19:04,  2.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 74/474 [03:19<18:57,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 75/474 [03:22<18:50,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 76/474 [03:25<18:47,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 77/474 [03:28<18:44,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▋        | 78/474 [03:31<18:40,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 79/474 [03:33<18:13,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 80/474 [03:36<18:18,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 81/474 [03:39<18:20,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 82/474 [03:42<18:24,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 83/474 [03:44<18:22,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 84/474 [03:47<17:50,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 85/474 [03:49<15:50,  2.44s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 86/474 [03:51<16:06,  2.49s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 87/474 [03:54<16:42,  2.59s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▊        | 88/474 [03:57<17:07,  2.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 89/474 [04:00<17:26,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 90/474 [04:03<17:35,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 91/474 [04:05<17:11,  2.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 92/474 [04:08<17:26,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 93/474 [04:11<17:39,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 94/474 [04:14<17:08,  2.71s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 95/474 [04:16<17:17,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 96/474 [04:19<17:33,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 97/474 [04:22<17:15,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 98/474 [04:25<17:25,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 99/474 [04:28<17:26,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 100/474 [04:30<17:29,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██▏       | 101/474 [04:33<17:26,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 102/474 [04:36<17:32,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 103/474 [04:39<17:16,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 104/474 [04:42<17:19,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 105/474 [04:44<16:44,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 106/474 [04:47<16:55,  2.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 107/474 [04:50<16:42,  2.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 108/474 [04:53<16:56,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 109/474 [04:55<17:01,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 110/474 [04:58<17:04,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 111/474 [05:01<17:06,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▎       | 112/474 [05:04<17:07,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 113/474 [05:07<17:04,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 114/474 [05:10<16:47,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 115/474 [05:12<16:50,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 116/474 [05:15<16:52,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 117/474 [05:18<16:53,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 118/474 [05:21<16:53,  2.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 119/474 [05:23<16:06,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 120/474 [05:26<15:50,  2.69s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 121/474 [05:29<16:07,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 122/474 [05:32<16:15,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 123/474 [05:35<16:22,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 124/474 [05:36<14:25,  2.47s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▋       | 125/474 [05:39<15:08,  2.60s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 126/474 [05:42<14:58,  2.58s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 127/474 [05:45<15:25,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 128/474 [05:47<15:26,  2.68s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 129/474 [05:50<15:13,  2.65s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 130/474 [05:53<15:35,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 131/474 [05:56<15:48,  2.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 132/474 [05:58<15:41,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 133/474 [06:01<15:50,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 134/474 [06:04<15:07,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 135/474 [06:05<13:26,  2.38s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▊       | 136/474 [06:08<14:02,  2.49s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 137/474 [06:11<13:59,  2.49s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 138/474 [06:13<14:27,  2.58s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 139/474 [06:16<14:53,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 140/474 [06:19<15:13,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 141/474 [06:22<15:23,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 142/474 [06:25<15:27,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 143/474 [06:28<15:30,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 144/474 [06:31<15:33,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 145/474 [06:33<15:19,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 146/474 [06:36<14:32,  2.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 147/474 [06:38<14:49,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 148/474 [06:41<14:59,  2.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███▏      | 149/474 [06:44<15:10,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 150/474 [06:47<14:42,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 151/474 [06:50<14:54,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 152/474 [06:52<14:51,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 153/474 [06:55<14:57,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 154/474 [06:58<14:30,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 155/474 [07:01<14:44,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 156/474 [07:04<14:50,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 157/474 [07:06<14:25,  2.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 158/474 [07:09<13:57,  2.65s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▎      | 159/474 [07:11<13:58,  2.66s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 160/474 [07:14<14:19,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 161/474 [07:17<14:33,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 162/474 [07:20<14:40,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 163/474 [07:23<14:43,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 164/474 [07:26<14:46,  2.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 165/474 [07:29<14:47,  2.87s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 166/474 [07:32<14:48,  2.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 167/474 [07:34<14:45,  2.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 168/474 [07:37<14:40,  2.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 169/474 [07:40<14:42,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 170/474 [07:43<14:39,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 171/474 [07:46<14:36,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▋      | 172/474 [07:49<14:04,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▋      | 173/474 [07:52<14:11,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 174/474 [07:54<13:30,  2.70s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 175/474 [07:57<13:45,  2.76s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 176/474 [08:00<13:54,  2.80s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 177/474 [08:02<13:42,  2.77s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 178/474 [08:05<13:51,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 179/474 [08:08<13:24,  2.73s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 180/474 [08:11<13:19,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 181/474 [08:13<13:25,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 182/474 [08:16<12:58,  2.67s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 183/474 [08:19<13:18,  2.74s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 184/474 [08:22<13:27,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 185/474 [08:24<13:23,  2.78s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 186/474 [08:27<13:31,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  73%|███████▎  | 346/474 [09:19<01:03,  2.02it/s]
# File cannot open
#  91%|█████████ | 432/474 [09:58<00:20,  2.00it/s]
# File cannot open
#  93%|█████████▎| 443/474 [10:01<00:09,  3.20it/s]
# File cannot open
# 100%|██████████| 474/474 [10:13<00:00,  1.29s/it]

# %%
#test
for row in tqdm(Data_test.values):
  mfccs,savepath  = feature_extractor(row)
  features_test.append(mfccs)
  imgpaths_test.append(savepath)
  diagnoses_test.append([row[-5],row[-4]])
# Out:
#   0%|          | 0/471 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 1/471 [00:03<24:28,  3.12s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   0%|          | 2/471 [00:06<24:01,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 3/471 [00:09<23:58,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 4/471 [00:12<23:27,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|          | 5/471 [00:15<23:26,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 6/471 [00:17<22:44,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   1%|▏         | 7/471 [00:20<22:52,  2.96s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 8/471 [00:23<22:58,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 9/471 [00:26<23:01,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 10/471 [00:29<22:38,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   2%|▏         | 11/471 [00:32<21:45,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 12/471 [00:35<21:27,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 13/471 [00:38<21:52,  2.86s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 14/471 [00:41<21:59,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 15/471 [00:44<22:13,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   3%|▎         | 16/471 [00:47<22:26,  2.96s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▎         | 17/471 [00:50<22:36,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 18/471 [00:53<22:37,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 19/471 [00:56<22:06,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 20/471 [00:59<22:17,  2.96s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   4%|▍         | 21/471 [01:02<22:26,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 22/471 [01:05<22:26,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▍         | 23/471 [01:08<22:21,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 24/471 [01:11<22:08,  2.97s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   5%|▌         | 25/471 [01:14<22:15,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 26/471 [01:17<22:26,  3.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 27/471 [01:19<21:24,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 28/471 [01:22<21:41,  2.94s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▌         | 29/471 [01:25<21:51,  2.97s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   6%|▋         | 30/471 [01:28<21:58,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 31/471 [01:31<22:03,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 32/471 [01:34<21:07,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 33/471 [01:37<21:33,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 34/471 [01:40<21:44,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   7%|▋         | 35/471 [01:43<21:18,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 36/471 [01:46<20:28,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 37/471 [01:48<20:22,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 38/471 [01:51<20:50,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 39/471 [01:54<21:07,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   8%|▊         | 40/471 [01:58<21:20,  2.97s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▊         | 41/471 [02:01<21:27,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 42/471 [02:04<21:29,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 43/471 [02:07<21:34,  3.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#   9%|▉         | 44/471 [02:09<21:03,  2.96s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 45/471 [02:13<21:11,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 46/471 [02:16<21:18,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|▉         | 47/471 [02:19<21:22,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 48/471 [02:21<20:32,  2.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  10%|█         | 49/471 [02:24<19:57,  2.84s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 50/471 [02:27<20:20,  2.90s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 51/471 [02:30<20:27,  2.92s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█         | 52/471 [02:33<20:45,  2.97s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█▏        | 53/471 [02:36<20:53,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  11%|█▏        | 54/471 [02:39<20:20,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 55/471 [02:42<20:17,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 56/471 [02:45<20:09,  2.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 57/471 [02:48<20:23,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  12%|█▏        | 58/471 [02:51<20:29,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 59/471 [02:54<20:34,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 60/471 [02:57<19:55,  2.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 61/471 [03:00<20:08,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 62/471 [03:03<20:17,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  13%|█▎        | 63/471 [03:06<20:24,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▎        | 64/471 [03:09<20:30,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 65/471 [03:12<20:23,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 66/471 [03:15<20:12,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 67/471 [03:18<19:53,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  14%|█▍        | 68/471 [03:20<19:44,  2.94s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 69/471 [03:24<19:58,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▍        | 70/471 [03:27<20:06,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 71/471 [03:30<20:13,  3.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 72/471 [03:33<20:13,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  15%|█▌        | 73/471 [03:35<19:13,  2.90s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 74/471 [03:38<19:32,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 75/471 [03:41<19:04,  2.89s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▌        | 76/471 [03:44<18:56,  2.88s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  16%|█▋        | 77/471 [03:47<19:17,  2.94s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 78/471 [03:50<19:31,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 79/471 [03:53<19:41,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 80/471 [03:56<19:46,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 81/471 [03:59<19:50,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  17%|█▋        | 82/471 [04:02<19:43,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 83/471 [04:06<19:51,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 84/471 [04:09<19:55,  3.09s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 85/471 [04:12<19:53,  3.09s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 86/471 [04:15<19:14,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  18%|█▊        | 87/471 [04:18<19:26,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▊        | 88/471 [04:21<19:30,  3.06s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 89/471 [04:24<19:16,  3.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 90/471 [04:27<19:25,  3.06s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  19%|█▉        | 91/471 [04:30<19:05,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 92/471 [04:33<19:13,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 93/471 [04:36<19:14,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|█▉        | 94/471 [04:39<18:58,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 95/471 [04:42<19:05,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  20%|██        | 96/471 [04:45<19:00,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 97/471 [04:48<19:05,  3.06s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 98/471 [04:51<18:47,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 99/471 [04:54<18:13,  2.94s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██        | 100/471 [04:57<18:30,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  21%|██▏       | 101/471 [04:59<16:25,  2.66s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 102/471 [05:02<16:44,  2.72s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 103/471 [05:05<17:22,  2.83s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 104/471 [05:08<17:45,  2.90s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  22%|██▏       | 105/471 [05:11<17:57,  2.95s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 106/471 [05:14<17:42,  2.91s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 107/471 [05:17<18:04,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 108/471 [05:20<18:16,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 109/471 [05:22<16:13,  2.69s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  23%|██▎       | 110/471 [05:25<16:47,  2.79s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▎       | 111/471 [05:28<16:56,  2.82s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 112/471 [05:31<17:26,  2.92s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 113/471 [05:34<17:28,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 114/471 [05:37<17:45,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  24%|██▍       | 115/471 [05:40<17:56,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 116/471 [05:43<18:00,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▍       | 117/471 [05:47<18:28,  3.13s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 118/471 [05:50<18:21,  3.12s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 119/471 [05:53<18:04,  3.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  25%|██▌       | 120/471 [05:56<18:01,  3.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 121/471 [05:59<17:19,  2.97s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 122/471 [06:02<17:32,  3.02s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▌       | 123/471 [06:05<17:39,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  26%|██▋       | 124/471 [06:08<17:25,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 125/471 [06:11<17:33,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 126/471 [06:14<17:37,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 127/471 [06:17<17:10,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 128/471 [06:20<16:50,  2.94s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  27%|██▋       | 129/471 [06:23<17:06,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 130/471 [06:26<17:07,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 131/471 [06:29<17:09,  3.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 132/471 [06:32<17:13,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 133/471 [06:35<17:16,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  28%|██▊       | 134/471 [06:38<17:21,  3.09s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▊       | 135/471 [06:41<17:01,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 136/471 [06:44<17:04,  3.06s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 137/471 [06:46<15:03,  2.70s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  29%|██▉       | 138/471 [06:48<13:39,  2.46s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 139/471 [06:51<14:20,  2.59s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 140/471 [06:54<15:10,  2.75s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|██▉       | 141/471 [06:56<13:41,  2.49s/it]
# File cannot open
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 142/471 [06:59<14:41,  2.68s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  30%|███       | 143/471 [07:02<15:20,  2.81s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 144/471 [07:05<15:30,  2.85s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 145/471 [07:08<15:55,  2.93s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 146/471 [07:11<15:47,  2.92s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███       | 147/471 [07:14<16:04,  2.98s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  31%|███▏      | 148/471 [07:17<16:13,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 149/471 [07:20<16:19,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 150/471 [07:23<16:20,  3.06s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 151/471 [07:27<16:22,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 152/471 [07:30<16:25,  3.09s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  32%|███▏      | 153/471 [07:32<15:52,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 154/471 [07:36<16:00,  3.03s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 155/471 [07:39<16:09,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 156/471 [07:42<15:49,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  33%|███▎      | 157/471 [07:45<15:57,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▎      | 158/471 [07:48<16:02,  3.07s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 159/471 [07:51<15:36,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 160/471 [07:54<15:44,  3.04s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 161/471 [07:57<15:54,  3.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  34%|███▍      | 162/471 [08:00<16:00,  3.11s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 163/471 [08:03<15:59,  3.12s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▍      | 164/471 [08:06<16:00,  3.13s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 165/471 [08:10<15:58,  3.13s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 166/471 [08:13<15:57,  3.14s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  35%|███▌      | 167/471 [08:16<15:55,  3.14s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 168/471 [08:19<15:51,  3.14s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 169/471 [08:22<15:48,  3.14s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▌      | 170/471 [08:25<15:46,  3.15s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  36%|███▋      | 171/471 [08:29<15:45,  3.15s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 172/471 [08:32<15:43,  3.16s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 173/471 [08:35<15:38,  3.15s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 174/471 [08:38<15:15,  3.08s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 175/471 [08:41<15:16,  3.10s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  37%|███▋      | 176/471 [08:44<15:20,  3.12s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 177/471 [08:47<14:57,  3.05s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 178/471 [08:50<15:04,  3.09s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 179/471 [08:53<14:36,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 180/471 [08:56<14:33,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  38%|███▊      | 181/471 [08:59<14:28,  3.00s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▊      | 182/471 [09:02<14:23,  2.99s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 183/471 [09:05<14:40,  3.06s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  39%|███▉      | 184/471 [09:08<14:24,  3.01s/it]/usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
#  49%|████▉     | 232/471 [09:29<01:23,  2.87it/s]
# File cannot open
#  64%|██████▍   | 303/471 [09:58<00:58,  2.88it/s]
# File cannot open
#  85%|████████▌ | 402/471 [10:57<00:32,  2.10it/s]
# File cannot open
#  88%|████████▊ | 414/471 [11:01<00:19,  2.90it/s]
# File cannot open
#  99%|█████████▊| 465/471 [11:24<00:02,  2.06it/s]
# File cannot open
# 100%|██████████| 471/471 [11:26<00:00,  1.46s/it]

# %%
isnone = lambda x: x is not None
label_train  = lambda x: 1 if  x == 'COVID-19' or x == 'positive_mild'   or  x == 'positive_moderate'  or  x == 'positive_asymp'  else 0
cast_x_train = list(map(isnone,features_train))
data_y_train = list(map(label_train,Data_train['STATUS']))

data_x_train = [features_train[i] for i in range(len(features_train)) if cast_x_train[i] == True]
data_xx_train= [imgpaths_train[i] for i in range(len(imgpaths_train)) if cast_x_train[i] == True]
data_xp_train= [diagnoses_train[i]for i in range(len(diagnoses_train))if cast_x_train[i] == True]
data_y_train = [data_y_train[i] for i in range(len(features_train)) if cast_x_train[i] == True]

# %%
isnone = lambda x: x is not None
label_val  = lambda x: 1 if  x == 'COVID-19' or x == 'positive_mild'   or  x == 'positive_moderate'  or  x == 'positive_asymp'  else 0
cast_x_val = list(map(isnone,features_val))
data_y_val = list(map(label_val,Data_val['STATUS']))

data_x_val = [features_val[i] for i in range(len(features_val)) if cast_x_val[i] == True]
data_xx_val= [imgpaths_val[i] for i in range(len(imgpaths_val)) if cast_x_val[i] == True]
data_xp_val= [diagnoses_val[i]for i in range(len(diagnoses_val))if cast_x_val[i] == True]
data_y_val = [data_y_val[i] for i in range(len(features_val)) if cast_x_val[i] == True]

# %%
isnone = lambda x: x is not None
label_test  = lambda x: 1 if  x == 'COVID-19' or x == 'positive_mild'   or  x == 'positive_moderate'  or  x == 'positive_asymp'  else 0
cast_x_test = list(map(isnone,features_test))
data_y_test = list(map(label_test,Data_test['STATUS']))

data_x_test = [features_test[i] for i in range(len(features_test)) if cast_x_test[i] == True]
data_xx_test = [imgpaths_test[i] for i in range(len(imgpaths_test)) if cast_x_test[i] == True]
data_xp_test = [diagnoses_test[i]for i in range(len(diagnoses_test))if cast_x_test[i] == True]
data_y_test = [data_y_test[i] for i in range(len(features_test)) if cast_x_test[i] == True]

# %%
assert len(data_x_train) == len(data_xx_train) == len(data_xp_train), "Data lengths do not match"

indices = np.arange(len(data_x_train))
NUM_shuf= 1
DATA_train    = {i:{} for i in range(NUM_shuf)}

for i in range(NUM_shuf):
  np.random.shuffle(indices)

  DATA_train[i]['MFCCS'] = np.array([data_x_train[i] for i in indices])
  DATA_train[i]['MEL']   = [data_xx_train[i] for i in indices]
  DATA_train[i]['EXTRA'] = np.array([data_xp_train[i] for i in indices])
  DATA_train[i]['LABELS']= np.array([data_y_train[i] for i in indices])

# %%
assert len(data_x_val) == len(data_xx_val) == len(data_xp_val), "Data lengths do not match"

indices = np.arange(len(data_x_val))
NUM_shuf= 1
DATA_val    = {i:{} for i in range(NUM_shuf)}

for i in range(NUM_shuf):
  np.random.shuffle(indices)

  DATA_val[i]['MFCCS'] = np.array([data_x_val[i] for i in indices])
  DATA_val[i]['MEL']   = [data_xx_val[i] for i in indices]
  DATA_val[i]['EXTRA'] = np.array([data_xp_val[i] for i in indices])
  DATA_val[i]['LABELS']= np.array([data_y_val[i] for i in indices])

# %%
assert len(data_x_test) == len(data_xx_test) == len(data_xp_test), "Data lengths do not match"

indices = np.arange(len(data_x_test))
NUM_shuf= 1
DATA_test    = {i:{} for i in range(NUM_shuf)}

for i in range(NUM_shuf):
  np.random.shuffle(indices)

  DATA_test[i]['MFCCS'] = np.array([data_x_test[i] for i in indices])
  DATA_test[i]['MEL']   = [data_xx_test[i] for i in indices]
  DATA_test[i]['EXTRA'] = np.array([data_xp_test[i] for i in indices])
  DATA_test[i]['LABELS']= np.array([data_y_test[i] for i in indices])

# %%
print(len(DATA_test[0]['MFCCS']),len(DATA_val[0]['MFCCS']),len(DATA_train[0]['MFCCS']))
# Out:
# 461 464 3707

# %%
# Save extracted features
# Note: mel specs not saved
import pickle
pickle.dump( DATA_train, open( "loaded_data.pickle", "wb" ) )

# Save extracted features
# Note: mel specs not saved
pickle.dump( DATA_val, open( "loaded_data.pickle", "wb" ) )

# Save extracted features
# Note: mel specs not saved
pickle.dump( DATA_test, open( "loaded_data.pickle", "wb" ) )

# %%
class CustomDataset(tf.keras.utils.Sequence):
  def __init__(self,imgfiles,labels,batch_size,target_size=(64,64),shuffle=False,scale=255,n_classes=1,n_channels=3):
    self.batch_size = batch_size
    self.dim        = target_size
    self.labels     = labels
    self.imgfiles   = imgfiles
    self.n_classes  = n_classes
    self.shuffle    = shuffle
    self.n_channels = n_channels
    self.scale      = scale

    self.c          = 0
    self.on_epoch_end()

  def __len__(self):
    # returns the number of batches
    return int(np.floor(len(self.imgfiles) / self.batch_size))

  def __getitem__(self, index):
    # returns one batch
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

    # Generate data
    X, y = self.__data_generation(indexes)
    return X, y

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.imgfiles))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)
  
  def __data_generation(self, list_IDs_temp):
    X = np.empty((self.batch_size, *self.dim, self.n_channels))
    y = np.empty((self.batch_size), dtype=int)

    # Generate data
    for i, ID in enumerate(list_IDs_temp):
        # Store sample
        img   = cv2.imread(self.imgfiles[ID])
        img   = cv2.resize(img,self.dim,interpolation = cv2.INTER_CUBIC)
        X[i,] = img / self.scale

        # Store class
        y[i] = self.labels[ID]

        self.c +=1
    return X, y #keras.utils.to_categorical(y, num_classes=self.n_classes)


class CustomPipeline(tf.keras.utils.Sequence):
  def __init__(self,data_x,data_y,batch_size=48,shuffle=False,n_classes=1):
    self.features   = data_x
    self.labels     = data_y
    self.batch_size = 48
    self.shuffle    = shuffle
    self.n_features = self.features.shape[1]
    self.n_classes  = 1
    self.on_epoch_end()

  def __len__(self):
    return int(np.floor(len(self.features) / self.batch_size))

  def __getitem__(self,index):
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
    X, y = self.__data_generation(indexes)
    return X, y

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.features))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)

  def __data_generation(self,indexes):
    X = np.empty((self.batch_size, self.n_features))
    y = np.empty((self.batch_size), dtype=int)

    for i, ID in enumerate(indexes):
      X[i,] = self.features[ID]
      y[i,] = self.labels[ID]
    return X, y

class MultipleInputGenerator(tf.keras.utils.Sequence):
  """Wrapper of two generatos for the combined input model"""

  def __init__(self, X1, X2, Y, batch_size,target_size=(64,64)):
      self.genX1 = CustomPipeline(X1, Y, batch_size=batch_size,shuffle=False)
      self.genX2 = CustomDataset (X2, Y, batch_size=batch_size,shuffle=False,target_size=target_size)

  def __len__(self):
      return self.genX1.__len__()

  def __getitem__(self, index):
      X1_batch, Y_batch = self.genX1.__getitem__(index)
      X2_batch, Y_batch = self.genX2.__getitem__(index)
      X_batch = [X1_batch, X2_batch]
      return X_batch, Y_batch

class TripleInputGenerator(tf.keras.utils.Sequence):
  """Wrapper of two generatos for the combined input model"""

  def __init__(self, X1, X2, X3, Y, batch_size,target_size=(64,64)):
      self.genX1 = CustomPipeline(X1, Y, batch_size=batch_size,shuffle=False)
      self.genX2 = CustomDataset (X2, Y, batch_size=batch_size,shuffle=False,target_size=target_size)
      self.genX3 = CustomPipeline(X3, Y, batch_size=batch_size,shuffle=False)
  def __len__(self):
      return self.genX1.__len__()

  def __getitem__(self, index):
      X1_batch, Y_batch = self.genX1.__getitem__(index)
      X2_batch, Y_batch = self.genX2.__getitem__(index)
      X3_batch, Y_batch = self.genX3.__getitem__(index)

      X_batch = [X1_batch, X2_batch, X3_batch]
      return X_batch, Y_batch

# %%
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class Evaluation(keras.callbacks.Callback):
  
  def __init__(self, val_data_gen, val_labels, test_data_gen, test_labels):
    super(Callback, self).__init__()
    self.test_data = test_data_gen
    self.val_labels = val_labels
    self.val_data = val_data_gen
    self.test_labels = test_labels

  def on_epoch_end(self, epoch, logs=None):
    y_preds = self.model.predict_generator(self.val_data)
    print(' | val_auc:', roc_auc_score(self.val_labels[:len(y_preds)], y_preds))

    y_preds = self.model.predict_generator(self.test_data)
    print(' | test_auc:', roc_auc_score(self.test_labels[:len(y_preds)], y_preds))

# %%
def build_model():
  '''Function to build ensemble model'''
  # First Model
  inp1   = Input(shape=39)
  lay1   = Dense(units=512,activation='relu',kernel_initializer='GlorotUniform')(inp1)
  lay2   = Dropout(0.4)(lay1)
  lay3   = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(lay2)
  lay4   = Dropout(0.2)(lay3)

  # Second Model
  inp2   = Input(shape=(64,64,3))
  lay1_  = Conv2D(32, (3, 3), strides=(2, 2))(inp2)
  lay2_  = AveragePooling2D((2, 2), strides=(2,2))(lay1_)
  lay3_  = BatchNormalization()(lay2_)
  lay4_  = Activation('relu')(lay3_)

  lay5_  = Conv2D(64, (3, 3), padding="same") (lay4_)
  lay6_  = AveragePooling2D((2, 2), strides=(2,2)) (lay5_)
  lay7_  = BatchNormalization()(lay6_)
  lay8_  = Activation('relu')(lay7_)

  lay9_  = Conv2D(64, (3, 3), padding="same") (lay8_)
  lay10_ = AveragePooling2D((2, 2), strides=(2,2)) (lay9_)
  lay11_ = BatchNormalization()(lay10_)
  lay12_ = Activation('relu')(lay11_)

  lay13_ = Flatten()(lay12_)
  lay14_ = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(lay13_)
  lay15_ = Dropout(rate=0.5)(lay14_)

  # Third model
  inp3   = Input(shape=2)
  lay31  = Dense(units=16,activation='relu',kernel_initializer='GlorotUniform')(inp3)
  lay32  = Dropout(0.4)(lay31)
  lay33  = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(lay32)
  lay43  = Dropout(0.2)(lay33)

  # merge input models
  merge = concatenate([lay15_, lay4,lay43])

  # interpretation model
  hidden1 = Dense(64, activation='relu')(merge)
  hidden2 = Dense(64, activation='relu')(hidden1)
  output  = Dense(1, activation='sigmoid')(hidden2)
  MERGM   = Model(inputs=[inp1, inp2,inp3], outputs=output)

  return MERGM

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=30,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# rm: cannot remove '/content/models': No such file or directory
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.5386149228130361
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5312506705001394
# 77/77 - 18s - loss: 1.1839 - auc: 0.5347 - val_loss: 0.7007 - val_auc: 0.5393 - 18s/epoch - 239ms/step
# Epoch 2/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.4428816466552316
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.4297423133864011
# 77/77 - 16s - loss: 0.6996 - auc: 0.5632 - val_loss: 0.6998 - val_auc: 0.4404 - 16s/epoch - 209ms/step
# Epoch 3/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.6656946826758148
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6408050292874461
# 77/77 - 16s - loss: 0.6771 - auc: 0.5752 - val_loss: 0.6876 - val_auc: 0.6647 - 16s/epoch - 212ms/step
# Epoch 4/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8236063464837049
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8314845409487845
# 77/77 - 16s - loss: 0.6345 - auc: 0.6708 - val_loss: 0.5689 - val_auc: 0.8245 - 16s/epoch - 214ms/step
# Epoch 5/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8185248713550599
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8287381723775398
# 77/77 - 16s - loss: 0.5614 - auc: 0.7740 - val_loss: 0.5398 - val_auc: 0.8184 - 16s/epoch - 212ms/step
# Epoch 6/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8460548885077188
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.842083807153432
# 77/77 - 16s - loss: 0.5225 - auc: 0.8087 - val_loss: 0.5131 - val_auc: 0.8459 - 16s/epoch - 202ms/step
# Epoch 7/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8376500857632934
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.837663870234085
# 77/77 - 15s - loss: 0.5002 - auc: 0.8258 - val_loss: 0.5190 - val_auc: 0.8373 - 15s/epoch - 197ms/step
# Epoch 8/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8133576329331047
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8181603621773554
# 77/77 - 16s - loss: 0.4902 - auc: 0.8341 - val_loss: 0.5940 - val_auc: 0.8133 - 16s/epoch - 204ms/step
# Epoch 9/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7840265866209263
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8031197030488983
# 77/77 - 16s - loss: 0.4784 - auc: 0.8450 - val_loss: 0.6626 - val_auc: 0.7843 - 16s/epoch - 212ms/step
# Epoch 10/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8375214408233276
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8287596283820028
# 77/77 - 18s - loss: 0.4554 - auc: 0.8616 - val_loss: 0.5450 - val_auc: 0.8378 - 18s/epoch - 231ms/step
# Epoch 11/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8262650085763293
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8486922565279893
# 77/77 - 15s - loss: 0.4364 - auc: 0.8749 - val_loss: 0.5510 - val_auc: 0.8264 - 15s/epoch - 200ms/step
# Epoch 12/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8331046312178387
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8457956959255047
# 77/77 - 17s - loss: 0.4226 - auc: 0.8824 - val_loss: 0.5478 - val_auc: 0.8329 - 17s/epoch - 225ms/step
# Epoch 13/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8495068610634648
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8407749908811981
# 77/77 - 16s - loss: 0.4073 - auc: 0.8919 - val_loss: 0.5454 - val_auc: 0.8486 - 16s/epoch - 211ms/step
# Epoch 14/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8556389365351629
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8477052803226984
# 77/77 - 16s - loss: 0.3983 - auc: 0.8986 - val_loss: 0.4871 - val_auc: 0.8553 - 16s/epoch - 210ms/step
# Epoch 15/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8244639794168096
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8438861115283113
# 77/77 - 15s - loss: 0.3679 - auc: 0.9135 - val_loss: 0.5552 - val_auc: 0.8246 - 15s/epoch - 200ms/step
# Epoch 16/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8352058319039452
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8444439676443453
# 77/77 - 15s - loss: 0.3675 - auc: 0.9143 - val_loss: 0.5219 - val_auc: 0.8349 - 15s/epoch - 199ms/step
# Epoch 17/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.829180960548885
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8460960799879846
# 77/77 - 16s - loss: 0.3340 - auc: 0.9292 - val_loss: 0.6101 - val_auc: 0.8285 - 16s/epoch - 208ms/step
# Epoch 18/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8288164665523156
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8625957474199155
# 77/77 - 16s - loss: 0.3107 - auc: 0.9396 - val_loss: 0.6023 - val_auc: 0.8287 - 16s/epoch - 207ms/step
# Epoch 19/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8349056603773584
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8559229300319695
# 77/77 - 16s - loss: 0.2822 - auc: 0.9506 - val_loss: 0.7523 - val_auc: 0.8326 - 16s/epoch - 207ms/step
# Epoch 20/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8262006861063464
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8337588774218465
# 77/77 - 16s - loss: 0.2622 - auc: 0.9574 - val_loss: 0.7211 - val_auc: 0.8223 - 16s/epoch - 207ms/step
# Epoch 21/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8482418524871355
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8760486622181217
# 77/77 - 16s - loss: 0.2611 - auc: 0.9581 - val_loss: 0.7038 - val_auc: 0.8485 - 16s/epoch - 206ms/step
# Epoch 22/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8334691252144082
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8619735232904929
# 77/77 - 16s - loss: 0.2072 - auc: 0.9738 - val_loss: 0.7367 - val_auc: 0.8298 - 16s/epoch - 207ms/step
# Epoch 23/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8697684391080617
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8849743600746669
# 77/77 - 16s - loss: 0.1926 - auc: 0.9773 - val_loss: 0.6881 - val_auc: 0.8657 - 16s/epoch - 207ms/step
# Epoch 24/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8373499142367066
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8503658248760915
# 77/77 - 16s - loss: 0.1856 - auc: 0.9787 - val_loss: 0.9623 - val_auc: 0.8389 - 16s/epoch - 207ms/step
# Epoch 25/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8624785591766723
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8689789087476131
# 77/77 - 16s - loss: 0.1749 - auc: 0.9813 - val_loss: 0.8110 - val_auc: 0.8566 - 16s/epoch - 205ms/step
# Epoch 26/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.867688679245283
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8814770313472224
# 77/77 - 16s - loss: 0.1606 - auc: 0.9840 - val_loss: 0.6596 - val_auc: 0.8635 - 16s/epoch - 204ms/step
# Epoch 27/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.854909948542024
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8657926920848799
# 77/77 - 16s - loss: 0.1308 - auc: 0.9896 - val_loss: 0.7746 - val_auc: 0.8527 - 16s/epoch - 202ms/step
# Epoch 28/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8580403087478559
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8679704765378592
# 77/77 - 15s - loss: 0.1291 - auc: 0.9896 - val_loss: 0.9680 - val_auc: 0.8472 - 15s/epoch - 198ms/step
# Epoch 29/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8566252144082332
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8752118780440707
# 77/77 - 15s - loss: 0.1077 - auc: 0.9926 - val_loss: 0.9145 - val_auc: 0.8502 - 15s/epoch - 198ms/step
# Epoch 30/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8494210977701543
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8798892870169717
# 77/77 - 15s - loss: 0.1026 - auc: 0.9932 - val_loss: 0.8403 - val_auc: 0.8437 - 15s/epoch - 199ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.7058430910110474 , AUC = 0.8706525564193726
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8494210977701543
# test 0.8798892870169717
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/0/030--0.840--0.103.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.8148148148148148
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ##9 epoch

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models/9epoch'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=9,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# rm: cannot remove '/content/models/9epoch': No such file or directory
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.5904159519725557
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5861994979294955
# 77/77 - 20s - loss: 1.1831 - auc: 0.5310 - val_loss: 0.6942 - val_auc: 0.5887 - 20s/epoch - 261ms/step
# Epoch 2/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.523606346483705
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5148797390949857
# 77/77 - 16s - loss: 0.7048 - auc: 0.5722 - val_loss: 0.7128 - val_auc: 0.5238 - 16s/epoch - 212ms/step
# Epoch 3/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7393867924528302
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7639624949041991
# 77/77 - 16s - loss: 0.6671 - auc: 0.6067 - val_loss: 0.7729 - val_auc: 0.7381 - 16s/epoch - 206ms/step
# Epoch 4/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8013078902229845
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7991503422232712
# 77/77 - 16s - loss: 0.5936 - auc: 0.7248 - val_loss: 0.7216 - val_auc: 0.8009 - 16s/epoch - 206ms/step
# Epoch 5/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8113636363636363
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8288025403909285
# 77/77 - 16s - loss: 0.5397 - auc: 0.7928 - val_loss: 0.5420 - val_auc: 0.8108 - 16s/epoch - 204ms/step
# Epoch 6/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8425171526586621
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8492286566395605
# 77/77 - 16s - loss: 0.5180 - auc: 0.8169 - val_loss: 0.4972 - val_auc: 0.8420 - 16s/epoch - 206ms/step
# Epoch 7/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8476843910806175
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8421267191623577
# 77/77 - 16s - loss: 0.4996 - auc: 0.8319 - val_loss: 0.5156 - val_auc: 0.8482 - 16s/epoch - 205ms/step
# Epoch 8/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8323970840480274
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8263565558821635
# 77/77 - 16s - loss: 0.4841 - auc: 0.8407 - val_loss: 0.5413 - val_auc: 0.8317 - 16s/epoch - 204ms/step
# Epoch 9/9
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8449828473413379
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8330722852790353
# 77/77 - 16s - loss: 0.4750 - auc: 0.8457 - val_loss: 0.5070 - val_auc: 0.8451 - 16s/epoch - 206ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.5165619254112244 , AUC = 0.8331366181373596
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8449828473413379
# test 0.8330722852790353
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/9epoch/0/009--0.507--0.475.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.7314814814814815
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ##50 epoch

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models/9epoch'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=50,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.5891938250428816
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6168386723024439
# 77/77 - 21s - loss: 1.1382 - auc: 0.5211 - val_loss: 0.6872 - val_auc: 0.5881 - 21s/epoch - 272ms/step
# Epoch 2/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7524442538593482
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7611946703284914
# 77/77 - 18s - loss: 0.7052 - auc: 0.5828 - val_loss: 0.6810 - val_auc: 0.7501 - 18s/epoch - 233ms/step
# Epoch 3/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.781367924528302
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7809556504387754
# 77/77 - 16s - loss: 0.6417 - auc: 0.6632 - val_loss: 0.6136 - val_auc: 0.7810 - 16s/epoch - 214ms/step
# Epoch 4/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8239065180102916
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.816379513806939
# 77/77 - 16s - loss: 0.5556 - auc: 0.7792 - val_loss: 0.5698 - val_auc: 0.8249 - 16s/epoch - 206ms/step
# Epoch 5/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8216123499142366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8340807174887894
# 77/77 - 16s - loss: 0.5290 - auc: 0.8049 - val_loss: 0.5500 - val_auc: 0.8222 - 16s/epoch - 205ms/step
# Epoch 6/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8289451114922815
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8317420130023387
# 77/77 - 18s - loss: 0.5118 - auc: 0.8217 - val_loss: 0.5629 - val_auc: 0.8293 - 18s/epoch - 240ms/step
# Epoch 7/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8349485420240137
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8421910871757461
# 77/77 - 16s - loss: 0.5072 - auc: 0.8241 - val_loss: 0.5020 - val_auc: 0.8349 - 16s/epoch - 205ms/step
# Epoch 8/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.767066895368782
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7800544982513357
# 77/77 - 17s - loss: 0.4825 - auc: 0.8426 - val_loss: 0.5848 - val_auc: 0.7665 - 17s/epoch - 220ms/step
# Epoch 9/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8430960548885077
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8364837899886284
# 77/77 - 18s - loss: 0.4828 - auc: 0.8442 - val_loss: 0.5000 - val_auc: 0.8428 - 18s/epoch - 236ms/step
# Epoch 10/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8401586620926242
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8491642886261721
# 77/77 - 16s - loss: 0.4624 - auc: 0.8578 - val_loss: 0.4892 - val_auc: 0.8404 - 16s/epoch - 211ms/step
# Epoch 11/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8452830188679246
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8441221275774026
# 77/77 - 16s - loss: 0.4504 - auc: 0.8651 - val_loss: 0.4901 - val_auc: 0.8450 - 16s/epoch - 205ms/step
# Epoch 12/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8313464837049742
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8375780462162337
# 77/77 - 16s - loss: 0.4191 - auc: 0.8861 - val_loss: 0.5296 - val_auc: 0.8311 - 16s/epoch - 206ms/step
# Epoch 13/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8458833619210978
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8509451369965885
# 77/77 - 16s - loss: 0.4122 - auc: 0.8887 - val_loss: 0.5721 - val_auc: 0.8455 - 16s/epoch - 207ms/step
# Epoch 14/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7878644939965695
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7879717638981268
# 77/77 - 16s - loss: 0.3923 - auc: 0.9007 - val_loss: 0.5898 - val_auc: 0.7873 - 16s/epoch - 206ms/step
# Epoch 15/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8300600343053174
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8375780462162337
# 77/77 - 17s - loss: 0.3889 - auc: 0.9025 - val_loss: 0.5528 - val_auc: 0.8292 - 17s/epoch - 221ms/step
# Epoch 16/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8240780445969126
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8130538331151973
# 77/77 - 16s - loss: 0.3829 - auc: 0.9059 - val_loss: 0.6691 - val_auc: 0.8222 - 16s/epoch - 207ms/step
# Epoch 17/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8418096054888506
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8380071663054905
# 77/77 - 16s - loss: 0.3464 - auc: 0.9239 - val_loss: 0.5703 - val_auc: 0.8418 - 16s/epoch - 209ms/step
# Epoch 18/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7871783876500857
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.832965005256721
# 77/77 - 16s - loss: 0.3282 - auc: 0.9324 - val_loss: 0.8471 - val_auc: 0.7833 - 16s/epoch - 212ms/step
# Epoch 19/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.848156089193825
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8468899521531101
# 77/77 - 16s - loss: 0.2974 - auc: 0.9451 - val_loss: 0.6517 - val_auc: 0.8469 - 16s/epoch - 206ms/step
# Epoch 20/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8371247855917666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8364623339841655
# 77/77 - 16s - loss: 0.2877 - auc: 0.9483 - val_loss: 0.6979 - val_auc: 0.8344 - 16s/epoch - 205ms/step
# Epoch 21/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8146869639794168
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8273006200785289
# 77/77 - 16s - loss: 0.2636 - auc: 0.9571 - val_loss: 0.6732 - val_auc: 0.8132 - 16s/epoch - 208ms/step
# Epoch 22/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8383576329331046
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8400669427339241
# 77/77 - 16s - loss: 0.2479 - auc: 0.9621 - val_loss: 0.8668 - val_auc: 0.8347 - 16s/epoch - 211ms/step
# Epoch 23/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8318717838765007
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.85826163451842
# 77/77 - 16s - loss: 0.2295 - auc: 0.9675 - val_loss: 0.8818 - val_auc: 0.8276 - 16s/epoch - 209ms/step
# Epoch 24/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8339193825042881
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8375780462162336
# 77/77 - 17s - loss: 0.2056 - auc: 0.9744 - val_loss: 0.8309 - val_auc: 0.8299 - 17s/epoch - 222ms/step
# Epoch 25/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8189965694682675
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8157572896775163
# 77/77 - 16s - loss: 0.1837 - auc: 0.9792 - val_loss: 1.0431 - val_auc: 0.8077 - 16s/epoch - 207ms/step
# Epoch 26/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8555531732418525
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8501083528225374
# 77/77 - 16s - loss: 0.1739 - auc: 0.9813 - val_loss: 0.7774 - val_auc: 0.8529 - 16s/epoch - 209ms/step
# Epoch 27/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8505574614065181
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8736348617160512
# 77/77 - 16s - loss: 0.1378 - auc: 0.9884 - val_loss: 0.8658 - val_auc: 0.8507 - 16s/epoch - 208ms/step
# Epoch 28/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8415094339622642
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.879138326860772
# 77/77 - 16s - loss: 0.1390 - auc: 0.9879 - val_loss: 0.8975 - val_auc: 0.8359 - 16s/epoch - 205ms/step
# Epoch 29/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8497534305317325
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8757911901645676
# 77/77 - 16s - loss: 0.1227 - auc: 0.9908 - val_loss: 1.0023 - val_auc: 0.8465 - 16s/epoch - 210ms/step
# Epoch 30/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8424313893653516
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8695260368614157
# 77/77 - 16s - loss: 0.1181 - auc: 0.9912 - val_loss: 1.1614 - val_auc: 0.8236 - 16s/epoch - 210ms/step
# Epoch 31/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8476843910806175
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8645589718282662
# 77/77 - 16s - loss: 0.1090 - auc: 0.9923 - val_loss: 1.0019 - val_auc: 0.8402 - 16s/epoch - 205ms/step
# Epoch 32/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8569146655231561
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8545604737485785
# 77/77 - 16s - loss: 0.0894 - auc: 0.9946 - val_loss: 0.9725 - val_auc: 0.8515 - 16s/epoch - 205ms/step
# Epoch 33/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.847545025728988
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8718003733344777
# 77/77 - 16s - loss: 0.0564 - auc: 0.9982 - val_loss: 1.1834 - val_auc: 0.8441 - 16s/epoch - 203ms/step
# Epoch 34/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8542881646655233
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8776578625528355
# 77/77 - 16s - loss: 0.0679 - auc: 0.9969 - val_loss: 1.0720 - val_auc: 0.8520 - 16s/epoch - 204ms/step
# Epoch 35/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8533126072041166
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8703628210354668
# 77/77 - 16s - loss: 0.0618 - auc: 0.9970 - val_loss: 1.1999 - val_auc: 0.8490 - 16s/epoch - 205ms/step
# Epoch 36/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8527015437392795
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8719720213701804
# 77/77 - 17s - loss: 0.0623 - auc: 0.9971 - val_loss: 1.2465 - val_auc: 0.8456 - 17s/epoch - 214ms/step
# Epoch 37/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8555531732418524
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8809835432445771
# 77/77 - 16s - loss: 0.0494 - auc: 0.9980 - val_loss: 1.0656 - val_auc: 0.8474 - 16s/epoch - 203ms/step
# Epoch 38/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8591337907375644
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8750831420172935
# 77/77 - 16s - loss: 0.0659 - auc: 0.9968 - val_loss: 1.0610 - val_auc: 0.8471 - 16s/epoch - 204ms/step
# Epoch 39/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.857032590051458
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8794601669277147
# 77/77 - 16s - loss: 0.0498 - auc: 0.9983 - val_loss: 1.2287 - val_auc: 0.8453 - 16s/epoch - 211ms/step
# Epoch 40/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8517581475128646
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8740425258008453
# 77/77 - 16s - loss: 0.0492 - auc: 0.9980 - val_loss: 1.0450 - val_auc: 0.8456 - 16s/epoch - 204ms/step
# Epoch 41/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.870368782161235
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8835046237689617
# 77/77 - 16s - loss: 0.0443 - auc: 0.9985 - val_loss: 1.2023 - val_auc: 0.8619 - 16s/epoch - 204ms/step
# Epoch 42/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8411878216123501
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8750616860128307
# 77/77 - 16s - loss: 0.0442 - auc: 0.9986 - val_loss: 1.2571 - val_auc: 0.8237 - 16s/epoch - 207ms/step
# Epoch 43/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8833404802744426
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8916579054648444
# 77/77 - 16s - loss: 0.0687 - auc: 0.9962 - val_loss: 1.0440 - val_auc: 0.8768 - 16s/epoch - 210ms/step
# Epoch 44/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8525300171526586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8735061256892742
# 77/77 - 16s - loss: 0.0493 - auc: 0.9981 - val_loss: 1.3701 - val_auc: 0.8414 - 16s/epoch - 214ms/step
# Epoch 45/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8680853344768439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.876434870298453
# 77/77 - 17s - loss: 0.0238 - auc: 0.9996 - val_loss: 1.3765 - val_auc: 0.8467 - 17s/epoch - 215ms/step
# Epoch 46/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8564215265866209
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.86955822086811
# 77/77 - 17s - loss: 0.0367 - auc: 0.9988 - val_loss: 1.5099 - val_auc: 0.8437 - 17s/epoch - 215ms/step
# Epoch 47/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8680531732418525
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8820992554766451
# 77/77 - 16s - loss: 0.0402 - auc: 0.9990 - val_loss: 1.3511 - val_auc: 0.8580 - 16s/epoch - 208ms/step
# Epoch 48/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8622534305317324
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.904209668075611
# 77/77 - 16s - loss: 0.0535 - auc: 0.9974 - val_loss: 1.1765 - val_auc: 0.8489 - 16s/epoch - 207ms/step
# Epoch 49/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8639686963979416
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9046817001737937
# 77/77 - 16s - loss: 0.0181 - auc: 0.9995 - val_loss: 1.4058 - val_auc: 0.8525 - 16s/epoch - 206ms/step
# Epoch 50/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8605917667238422
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9052931963009848
# 77/77 - 16s - loss: 0.0153 - auc: 0.9996 - val_loss: 1.4952 - val_auc: 0.8537 - 16s/epoch - 208ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 1.0332732200622559 , AUC = 0.8867766857147217
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8605917667238422
# test 0.9052931963009848
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/9epoch/0/050--1.495--0.015.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.8379629629629629
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ##100 epoch(0.01 LR)

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models/100epoch'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()
  optimizer = keras.optimizers.Adam(lr=0.01)
  MERGM.compile(
      optimizer = optimizer,
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=100,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# rm: cannot remove '/content/models/100epoch': No such file or directory
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.5662628644939965
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5749350955864999
# 77/77 - 17s - loss: 2.0591 - auc: 0.5265 - val_loss: 0.6591 - val_auc: 0.5663 - 17s/epoch - 224ms/step
# Epoch 2/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7673670668953687
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7728023687428927
# 77/77 - 15s - loss: 0.6542 - auc: 0.6218 - val_loss: 0.5779 - val_auc: 0.7686 - 15s/epoch - 201ms/step
# Epoch 3/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7735205831903945
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7742506490441351
# 77/77 - 15s - loss: 0.5646 - auc: 0.7598 - val_loss: 0.5578 - val_auc: 0.7695 - 15s/epoch - 201ms/step
# Epoch 4/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7820325900514579
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7853863153603536
# 77/77 - 16s - loss: 0.5612 - auc: 0.7691 - val_loss: 0.5207 - val_auc: 0.7820 - 16s/epoch - 204ms/step
# Epoch 5/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7808319039451115
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7965327096788035
# 77/77 - 16s - loss: 0.5542 - auc: 0.7835 - val_loss: 0.5414 - val_auc: 0.7809 - 16s/epoch - 205ms/step
# Epoch 6/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7945325900514579
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7888085480721779
# 77/77 - 16s - loss: 0.5532 - auc: 0.7689 - val_loss: 0.5811 - val_auc: 0.7950 - 16s/epoch - 203ms/step
# Epoch 7/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8139794168096055
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8099641684725472
# 77/77 - 16s - loss: 0.5426 - auc: 0.7963 - val_loss: 0.5417 - val_auc: 0.8148 - 16s/epoch - 208ms/step
# Epoch 8/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8401157804459691
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8330722852790352
# 77/77 - 16s - loss: 0.5318 - auc: 0.8019 - val_loss: 0.5325 - val_auc: 0.8406 - 16s/epoch - 204ms/step
# Epoch 9/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8223842195540308
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8136760572446199
# 77/77 - 16s - loss: 0.5094 - auc: 0.8207 - val_loss: 0.5385 - val_auc: 0.8219 - 16s/epoch - 204ms/step
# Epoch 10/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8467838765008576
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8335121333705238
# 77/77 - 16s - loss: 0.5055 - auc: 0.8215 - val_loss: 0.5014 - val_auc: 0.8468 - 16s/epoch - 202ms/step
# Epoch 11/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8041166380789023
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7911901645675542
# 77/77 - 15s - loss: 0.5113 - auc: 0.8227 - val_loss: 0.5275 - val_auc: 0.8050 - 15s/epoch - 200ms/step
# Epoch 12/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8408447684391082
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8388332224773103
# 77/77 - 15s - loss: 0.5017 - auc: 0.8284 - val_loss: 0.5223 - val_auc: 0.8410 - 15s/epoch - 201ms/step
# Epoch 13/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8238850771869641
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8197373785053748
# 77/77 - 15s - loss: 0.4816 - auc: 0.8398 - val_loss: 0.5209 - val_auc: 0.8236 - 15s/epoch - 201ms/step
# Epoch 14/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.801114922813036
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.808118952088742
# 77/77 - 16s - loss: 0.4655 - auc: 0.8511 - val_loss: 0.5540 - val_auc: 0.8017 - 16s/epoch - 204ms/step
# Epoch 15/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8519403945111492
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.83958418263351
# 77/77 - 16s - loss: 0.4681 - auc: 0.8522 - val_loss: 0.5013 - val_auc: 0.8514 - 16s/epoch - 204ms/step
# Epoch 16/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.833040308747856
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8402815027785526
# 77/77 - 15s - loss: 0.4707 - auc: 0.8524 - val_loss: 0.5126 - val_auc: 0.8329 - 15s/epoch - 201ms/step
# Epoch 17/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7639150943396226
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7721157766000815
# 77/77 - 15s - loss: 0.4657 - auc: 0.8531 - val_loss: 0.7352 - val_auc: 0.7628 - 15s/epoch - 200ms/step
# Epoch 18/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8435141509433963
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8339090694530864
# 77/77 - 15s - loss: 0.4578 - auc: 0.8594 - val_loss: 0.4980 - val_auc: 0.8445 - 15s/epoch - 200ms/step
# Epoch 19/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7809391080617495
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7806016263651383
# 77/77 - 15s - loss: 0.4439 - auc: 0.8680 - val_loss: 0.6771 - val_auc: 0.7802 - 15s/epoch - 200ms/step
# Epoch 20/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8201222126929674
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8232776192417448
# 77/77 - 15s - loss: 0.4363 - auc: 0.8719 - val_loss: 0.5694 - val_auc: 0.8200 - 15s/epoch - 201ms/step
# Epoch 21/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8412843053173242
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8463964640504646
# 77/77 - 15s - loss: 0.4444 - auc: 0.8678 - val_loss: 0.5025 - val_auc: 0.8415 - 15s/epoch - 201ms/step
# Epoch 22/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7639686963979417
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7754521852940546
# 77/77 - 16s - loss: 0.4369 - auc: 0.8742 - val_loss: 0.9489 - val_auc: 0.7592 - 16s/epoch - 203ms/step
# Epoch 23/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8445647512864494
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8423520072092174
# 77/77 - 15s - loss: 0.4123 - auc: 0.8844 - val_loss: 0.5017 - val_auc: 0.8436 - 15s/epoch - 200ms/step
# Epoch 24/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.783426243567753
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8067886798120454
# 77/77 - 15s - loss: 0.4050 - auc: 0.8912 - val_loss: 0.6813 - val_auc: 0.7828 - 15s/epoch - 198ms/step
# Epoch 25/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8525300171526586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8480593043963353
# 77/77 - 15s - loss: 0.4035 - auc: 0.8914 - val_loss: 0.4986 - val_auc: 0.8525 - 15s/epoch - 200ms/step
# Epoch 26/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8479845626072041
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8665865642500055
# 77/77 - 15s - loss: 0.3927 - auc: 0.8985 - val_loss: 0.5452 - val_auc: 0.8480 - 15s/epoch - 200ms/step
# Epoch 27/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8218481989708405
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8314309009376274
# 77/77 - 15s - loss: 0.3825 - auc: 0.9034 - val_loss: 0.6223 - val_auc: 0.8217 - 15s/epoch - 200ms/step
# Epoch 28/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8298456260720412
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8439504795416998
# 77/77 - 15s - loss: 0.3767 - auc: 0.9069 - val_loss: 0.5857 - val_auc: 0.8293 - 15s/epoch - 200ms/step
# Epoch 29/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.815673241852487
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8339090694530864
# 77/77 - 16s - loss: 0.3734 - auc: 0.9080 - val_loss: 0.5792 - val_auc: 0.8138 - 16s/epoch - 202ms/step
# Epoch 30/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8348413379073756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8495075846975776
# 77/77 - 16s - loss: 0.3765 - auc: 0.9080 - val_loss: 0.5205 - val_auc: 0.8353 - 16s/epoch - 204ms/step
# Epoch 31/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8275943396226415
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8525972493402278
# 77/77 - 15s - loss: 0.3550 - auc: 0.9184 - val_loss: 0.5378 - val_auc: 0.8274 - 15s/epoch - 198ms/step
# Epoch 32/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8457868782161235
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8769069023966357
# 77/77 - 15s - loss: 0.3306 - auc: 0.9280 - val_loss: 0.5165 - val_auc: 0.8455 - 15s/epoch - 199ms/step
# Epoch 33/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8428602058319038
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8546784817731242
# 77/77 - 15s - loss: 0.3204 - auc: 0.9328 - val_loss: 0.5848 - val_auc: 0.8401 - 15s/epoch - 199ms/step
# Epoch 34/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8331046312178386
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8575643143733773
# 77/77 - 16s - loss: 0.3255 - auc: 0.9323 - val_loss: 0.5706 - val_auc: 0.8319 - 16s/epoch - 201ms/step
# Epoch 35/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8429888507718695
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8553114339047782
# 77/77 - 16s - loss: 0.2971 - auc: 0.9428 - val_loss: 0.5975 - val_auc: 0.8420 - 16s/epoch - 204ms/step
# Epoch 36/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8204331046312179
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8496363207243547
# 77/77 - 15s - loss: 0.3143 - auc: 0.9361 - val_loss: 0.6509 - val_auc: 0.8168 - 15s/epoch - 198ms/step
# Epoch 37/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8106989708404803
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8534233055120476
# 77/77 - 15s - loss: 0.2759 - auc: 0.9513 - val_loss: 0.8164 - val_auc: 0.8064 - 15s/epoch - 199ms/step
# Epoch 38/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8408018867924528
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8561482180788293
# 77/77 - 15s - loss: 0.2756 - auc: 0.9501 - val_loss: 0.6486 - val_auc: 0.8379 - 15s/epoch - 198ms/step
# Epoch 39/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8616209262435677
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8755659021177077
# 77/77 - 15s - loss: 0.2603 - auc: 0.9567 - val_loss: 0.5994 - val_auc: 0.8599 - 15s/epoch - 198ms/step
# Epoch 40/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8254288164665524
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8480163923874096
# 77/77 - 15s - loss: 0.2681 - auc: 0.9541 - val_loss: 0.7243 - val_auc: 0.8246 - 15s/epoch - 200ms/step
# Epoch 41/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8510077186963979
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8737206857339026
# 77/77 - 15s - loss: 0.2612 - auc: 0.9575 - val_loss: 0.5997 - val_auc: 0.8503 - 15s/epoch - 200ms/step
# Epoch 42/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8250643224699828
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8632716115604953
# 77/77 - 15s - loss: 0.2565 - auc: 0.9585 - val_loss: 0.6724 - val_auc: 0.8234 - 15s/epoch - 199ms/step
# Epoch 43/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.848048885077187
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8682494045958761
# 77/77 - 15s - loss: 0.2500 - auc: 0.9616 - val_loss: 0.6191 - val_auc: 0.8440 - 15s/epoch - 201ms/step
# Epoch 44/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8429459691252144
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8833007917265647
# 77/77 - 16s - loss: 0.2514 - auc: 0.9609 - val_loss: 0.7116 - val_auc: 0.8422 - 16s/epoch - 210ms/step
# Epoch 45/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8507182675814751
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8835904477868131
# 77/77 - 16s - loss: 0.2397 - auc: 0.9643 - val_loss: 0.6858 - val_auc: 0.8469 - 16s/epoch - 211ms/step
# Epoch 46/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8257718696397941
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8732808376424142
# 77/77 - 16s - loss: 0.2078 - auc: 0.9736 - val_loss: 0.7871 - val_auc: 0.8227 - 16s/epoch - 204ms/step
# Epoch 47/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8415415951972556
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8709528611581951
# 77/77 - 16s - loss: 0.1883 - auc: 0.9779 - val_loss: 0.6875 - val_auc: 0.8387 - 16s/epoch - 204ms/step
# Epoch 48/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8173241852487135
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.859345162743794
# 77/77 - 16s - loss: 0.1742 - auc: 0.9810 - val_loss: 0.8227 - val_auc: 0.8130 - 16s/epoch - 202ms/step
# Epoch 49/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8548777873070326
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8832793357221018
# 77/77 - 16s - loss: 0.1871 - auc: 0.9780 - val_loss: 0.6980 - val_auc: 0.8532 - 16s/epoch - 207ms/step
# Epoch 50/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8317431389365352
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8634539875984294
# 77/77 - 16s - loss: 0.1793 - auc: 0.9802 - val_loss: 0.8525 - val_auc: 0.8258 - 16s/epoch - 205ms/step
# Epoch 51/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8517474271012008
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8873559765700432
# 77/77 - 16s - loss: 0.1504 - auc: 0.9858 - val_loss: 0.8069 - val_auc: 0.8447 - 16s/epoch - 203ms/step
# Epoch 52/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8620926243567753
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8868946724740918
# 77/77 - 16s - loss: 0.1451 - auc: 0.9867 - val_loss: 0.8800 - val_auc: 0.8566 - 16s/epoch - 203ms/step
# Epoch 53/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8591123499142366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8948226661231146
# 77/77 - 15s - loss: 0.1405 - auc: 0.9877 - val_loss: 1.0732 - val_auc: 0.8553 - 15s/epoch - 199ms/step
# Epoch 54/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8708940823327616
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9043705881090823
# 77/77 - 16s - loss: 0.1336 - auc: 0.9888 - val_loss: 0.7110 - val_auc: 0.8638 - 16s/epoch - 203ms/step
# Epoch 55/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.836159948542024
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8564807861480035
# 77/77 - 16s - loss: 0.1311 - auc: 0.9894 - val_loss: 1.5839 - val_auc: 0.8277 - 16s/epoch - 205ms/step
# Epoch 56/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8711406518010292
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.884824168043427
# 77/77 - 16s - loss: 0.1503 - auc: 0.9859 - val_loss: 0.6927 - val_auc: 0.8663 - 16s/epoch - 204ms/step
# Epoch 57/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.868364065180103
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8997253631428755
# 77/77 - 16s - loss: 0.1202 - auc: 0.9904 - val_loss: 0.7794 - val_auc: 0.8636 - 16s/epoch - 204ms/step
# Epoch 58/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8819039451114923
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8944364580427833
# 77/77 - 16s - loss: 0.1212 - auc: 0.9908 - val_loss: 0.7370 - val_auc: 0.8791 - 16s/epoch - 207ms/step
# Epoch 59/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.868803602058319
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9051000922608191
# 77/77 - 16s - loss: 0.1228 - auc: 0.9904 - val_loss: 0.8755 - val_auc: 0.8655 - 16s/epoch - 206ms/step
# Epoch 60/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8516723842195539
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8970755465917137
# 77/77 - 16s - loss: 0.1030 - auc: 0.9923 - val_loss: 1.0110 - val_auc: 0.8514 - 16s/epoch - 204ms/step
# Epoch 61/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8798241852487136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.899639539125024
# 77/77 - 15s - loss: 0.1150 - auc: 0.9919 - val_loss: 0.8869 - val_auc: 0.8705 - 15s/epoch - 200ms/step
# Epoch 62/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8691252144082333
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9045636921492479
# 77/77 - 15s - loss: 0.1146 - auc: 0.9913 - val_loss: 0.9428 - val_auc: 0.8612 - 15s/epoch - 200ms/step
# Epoch 63/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8670883361921098
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9032656038792455
# 77/77 - 16s - loss: 0.0896 - auc: 0.9943 - val_loss: 0.9241 - val_auc: 0.8621 - 16s/epoch - 214ms/step
# Epoch 64/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8739065180102916
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8895659450297166
# 77/77 - 16s - loss: 0.0785 - auc: 0.9960 - val_loss: 0.9475 - val_auc: 0.8667 - 16s/epoch - 204ms/step
# Epoch 65/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8545990566037734
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8913360653979016
# 77/77 - 16s - loss: 0.1084 - auc: 0.9924 - val_loss: 0.9938 - val_auc: 0.8465 - 16s/epoch - 202ms/step
# Epoch 66/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8392045454545455
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8890295449181455
# 77/77 - 15s - loss: 0.0884 - auc: 0.9947 - val_loss: 1.4642 - val_auc: 0.8271 - 15s/epoch - 198ms/step
# Epoch 67/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8320433104631217
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8808762632222628
# 77/77 - 15s - loss: 0.0850 - auc: 0.9948 - val_loss: 1.1888 - val_auc: 0.8195 - 15s/epoch - 201ms/step
# Epoch 68/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8327508576329332
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8949835861565859
# 77/77 - 16s - loss: 0.0807 - auc: 0.9957 - val_loss: 1.2063 - val_auc: 0.8233 - 16s/epoch - 203ms/step
# Epoch 69/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8618460548885076
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9075246207651211
# 77/77 - 16s - loss: 0.0719 - auc: 0.9965 - val_loss: 1.0573 - val_auc: 0.8553 - 16s/epoch - 203ms/step
# Epoch 70/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8481239279588335
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8801682150749888
# 77/77 - 15s - loss: 0.0821 - auc: 0.9954 - val_loss: 1.1286 - val_auc: 0.8350 - 15s/epoch - 200ms/step
# Epoch 71/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8575793310463122
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8979659707769221
# 77/77 - 15s - loss: 0.0796 - auc: 0.9950 - val_loss: 1.1596 - val_auc: 0.8525 - 15s/epoch - 198ms/step
# Epoch 72/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8756217838765008
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9006694273392409
# 77/77 - 16s - loss: 0.0809 - auc: 0.9947 - val_loss: 0.9272 - val_auc: 0.8727 - 16s/epoch - 202ms/step
# Epoch 73/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8626179245283019
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
# ...
#   app.launch_new_instance()
#  | test_auc: 0.89539125024138
# 77/77 - 16s - loss: 0.0732 - auc: 0.9960 - val_loss: 0.8599 - val_auc: 0.8486 - 16s/epoch - 206ms/step
# Epoch 78/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8739065180102916
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9024824597163517
# 77/77 - 16s - loss: 0.0691 - auc: 0.9965 - val_loss: 1.3748 - val_auc: 0.8635 - 16s/epoch - 204ms/step
# Epoch 79/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8566788164665524
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8906816572617846
# 77/77 - 16s - loss: 0.0685 - auc: 0.9957 - val_loss: 1.5277 - val_auc: 0.8484 - 16s/epoch - 202ms/step
# Epoch 80/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8588872212692966
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8904563692149248
# 77/77 - 15s - loss: 0.0512 - auc: 0.9978 - val_loss: 1.3622 - val_auc: 0.8468 - 15s/epoch - 200ms/step
# Epoch 81/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.858930102915952
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8998970111785782
# 77/77 - 15s - loss: 0.0623 - auc: 0.9969 - val_loss: 1.1114 - val_auc: 0.8483 - 15s/epoch - 201ms/step
# Epoch 82/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8457761578044598
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8799536550303602
# 77/77 - 15s - loss: 0.0721 - auc: 0.9954 - val_loss: 1.1203 - val_auc: 0.8354 - 15s/epoch - 198ms/step
# Epoch 83/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8576007718696397
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9008947153861008
# 77/77 - 15s - loss: 0.0654 - auc: 0.9964 - val_loss: 0.8396 - val_auc: 0.8519 - 15s/epoch - 201ms/step
# Epoch 84/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8449721269296742
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8981483468148561
# 77/77 - 16s - loss: 0.0623 - auc: 0.9971 - val_loss: 1.0924 - val_auc: 0.8323 - 16s/epoch - 202ms/step
# Epoch 85/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8639579759862779
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8996824511339498
# 77/77 - 15s - loss: 0.0795 - auc: 0.9954 - val_loss: 0.9129 - val_auc: 0.8533 - 15s/epoch - 201ms/step
# Epoch 86/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8570647512864494
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8797498229879631
# 77/77 - 15s - loss: 0.0779 - auc: 0.9960 - val_loss: 0.8799 - val_auc: 0.8492 - 15s/epoch - 199ms/step
# Epoch 87/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8734240994854203
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9080395648722295
# 77/77 - 15s - loss: 0.0609 - auc: 0.9970 - val_loss: 0.8769 - val_auc: 0.8628 - 15s/epoch - 200ms/step
# Epoch 88/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8666380789022298
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.896678610509151
# 77/77 - 15s - loss: 0.0447 - auc: 0.9983 - val_loss: 1.3048 - val_auc: 0.8480 - 15s/epoch - 198ms/step
# Epoch 89/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8591123499142367
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8853927521616923
# 77/77 - 15s - loss: 0.0523 - auc: 0.9972 - val_loss: 1.2683 - val_auc: 0.8442 - 15s/epoch - 199ms/step
# Epoch 90/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.875718267581475
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8937176818932777
# 77/77 - 15s - loss: 0.0821 - auc: 0.9947 - val_loss: 0.7997 - val_auc: 0.8675 - 15s/epoch - 199ms/step
# Epoch 91/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8583297598627788
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8996073551183299
# 77/77 - 15s - loss: 0.0461 - auc: 0.9978 - val_loss: 1.4909 - val_auc: 0.8353 - 15s/epoch - 201ms/step
# Epoch 92/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8681174957118354
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8995215311004785
# 77/77 - 16s - loss: 0.0500 - auc: 0.9978 - val_loss: 1.3861 - val_auc: 0.8467 - 16s/epoch - 212ms/step
# Epoch 93/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8217945969125214
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8743107258566309
# 77/77 - 17s - loss: 0.0555 - auc: 0.9974 - val_loss: 1.3495 - val_auc: 0.8037 - 17s/epoch - 216ms/step
# Epoch 94/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8562392795883362
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8995966271160984
# 77/77 - 17s - loss: 0.0670 - auc: 0.9959 - val_loss: 1.4173 - val_auc: 0.8374 - 17s/epoch - 216ms/step
# Epoch 95/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8544918524871357
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9021928036561032
# 77/77 - 16s - loss: 0.0664 - auc: 0.9961 - val_loss: 1.3009 - val_auc: 0.8426 - 16s/epoch - 212ms/step
# Epoch 96/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8564536878216122
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9070633166691698
# 77/77 - 16s - loss: 0.0783 - auc: 0.9957 - val_loss: 1.5376 - val_auc: 0.8364 - 16s/epoch - 208ms/step
# Epoch 97/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8815394511149228
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.9062050764906558
# 77/77 - 16s - loss: 0.0599 - auc: 0.9966 - val_loss: 0.9359 - val_auc: 0.8782 - 16s/epoch - 212ms/step
# Epoch 98/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8500536020583189
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8896839530542623
# 77/77 - 16s - loss: 0.0434 - auc: 0.9975 - val_loss: 1.2122 - val_auc: 0.8406 - 16s/epoch - 213ms/step
# Epoch 99/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8542667238421955
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8834080717488788
# 77/77 - 17s - loss: 0.0450 - auc: 0.9980 - val_loss: 1.2366 - val_auc: 0.8456 - 17s/epoch - 218ms/step
# Epoch 100/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8546419382504289
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8931169137683181
# 77/77 - 17s - loss: 0.0463 - auc: 0.9978 - val_loss: 1.5330 - val_auc: 0.8377 - 17s/epoch - 216ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 1.3508416414260864 , AUC = 0.8791598081588745
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8546419382504289
# test 0.8931169137683181
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/100epoch/0/100--1.533--0.046.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.8217592592592593
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ## try 50 epoch(augmantation in train and validation only)

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=50,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# rm: cannot remove '/content/models': No such file or directory
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.6394244172331711
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5458372712432339
# 77/77 - 18s - loss: 1.2378 - auc: 0.5309 - val_loss: 0.6970 - val_auc: 0.6383 - 18s/epoch - 232ms/step
# Epoch 2/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.443267354335099
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5028352951284475
# 77/77 - 18s - loss: 0.7110 - auc: 0.5777 - val_loss: 0.7015 - val_auc: 0.4448 - 18s/epoch - 236ms/step
# Epoch 3/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7481503720700822
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7111220895265917
# 77/77 - 15s - loss: 0.6817 - auc: 0.6040 - val_loss: 0.6717 - val_auc: 0.7498 - 15s/epoch - 200ms/step
# Epoch 4/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7716326049194742
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7604605206632873
# 77/77 - 15s - loss: 0.6486 - auc: 0.6494 - val_loss: 0.6230 - val_auc: 0.7707 - 15s/epoch - 199ms/step
# Epoch 5/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7883382299328774
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7820044677377782
# 77/77 - 15s - loss: 0.5546 - auc: 0.7736 - val_loss: 0.5674 - val_auc: 0.7881 - 15s/epoch - 198ms/step
# Epoch 6/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.822221269112822
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7972334392989089
# 77/77 - 15s - loss: 0.5145 - auc: 0.8159 - val_loss: 0.5123 - val_auc: 0.8219 - 15s/epoch - 198ms/step
# Epoch 7/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8305204692157577
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8076724804536474
# 77/77 - 15s - loss: 0.4992 - auc: 0.8280 - val_loss: 0.5144 - val_auc: 0.8307 - 15s/epoch - 199ms/step
# Epoch 8/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8450172631940126
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7962024228885644
# 77/77 - 15s - loss: 0.4985 - auc: 0.8329 - val_loss: 0.4985 - val_auc: 0.8454 - 15s/epoch - 198ms/step
# Epoch 9/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.834487787094422
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7872239883151474
# 77/77 - 16s - loss: 0.4835 - auc: 0.8434 - val_loss: 0.5493 - val_auc: 0.8348 - 16s/epoch - 202ms/step
# Epoch 10/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.851901095837533
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8013360254317381
# 77/77 - 15s - loss: 0.4796 - auc: 0.8468 - val_loss: 0.4721 - val_auc: 0.8519 - 15s/epoch - 198ms/step
# Epoch 11/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8394201282408699
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.811001804278718
# 77/77 - 15s - loss: 0.4620 - auc: 0.8594 - val_loss: 0.5131 - val_auc: 0.8396 - 15s/epoch - 199ms/step
# Epoch 12/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8277969591044584
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8125698084027837
# 77/77 - 15s - loss: 0.4510 - auc: 0.8668 - val_loss: 0.5145 - val_auc: 0.8274 - 15s/epoch - 198ms/step
# Epoch 13/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.85591130363921
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8272188332330954
# 77/77 - 15s - loss: 0.4422 - auc: 0.8720 - val_loss: 0.4674 - val_auc: 0.8558 - 15s/epoch - 198ms/step
# Epoch 14/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8558469687546911
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8333404931695162
# 77/77 - 16s - loss: 0.4176 - auc: 0.8889 - val_loss: 0.4775 - val_auc: 0.8555 - 16s/epoch - 202ms/step
# Epoch 15/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8629238060517681
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8442306040037805
# 77/77 - 16s - loss: 0.4196 - auc: 0.8868 - val_loss: 0.4725 - val_auc: 0.8630 - 16s/epoch - 202ms/step
# Epoch 16/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8585061439814716
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8239969069507689
# 77/77 - 15s - loss: 0.4030 - auc: 0.8960 - val_loss: 0.4582 - val_auc: 0.8588 - 15s/epoch - 200ms/step
# Epoch 17/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8642748386266648
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8346077841738981
# 77/77 - 15s - loss: 0.3815 - auc: 0.9076 - val_loss: 0.4927 - val_auc: 0.8641 - 15s/epoch - 197ms/step
# Epoch 18/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8782140636057558
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8317724890454506
# 77/77 - 15s - loss: 0.3676 - auc: 0.9135 - val_loss: 0.4544 - val_auc: 0.8782 - 15s/epoch - 198ms/step
# Epoch 19/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8601359610559498
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8227725749634849
# 77/77 - 15s - loss: 0.3507 - auc: 0.9220 - val_loss: 0.5119 - val_auc: 0.8599 - 15s/epoch - 198ms/step
# Epoch 20/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8396774677789454
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8334264112037117
# 77/77 - 15s - loss: 0.3280 - auc: 0.9326 - val_loss: 0.5125 - val_auc: 0.8398 - 15s/epoch - 197ms/step
# Epoch 21/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8484270120735133
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8341781940029211
# 77/77 - 15s - loss: 0.3156 - auc: 0.9373 - val_loss: 0.6165 - val_auc: 0.8481 - 15s/epoch - 197ms/step
# Epoch 22/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8715875705003109
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8468725835552883
# 77/77 - 16s - loss: 0.2922 - auc: 0.9465 - val_loss: 0.4549 - val_auc: 0.8716 - 16s/epoch - 205ms/step
# Epoch 23/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8760481224936201
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.836820173554429
# 77/77 - 15s - loss: 0.2691 - auc: 0.9548 - val_loss: 0.5713 - val_auc: 0.8739 - 15s/epoch - 198ms/step
# Epoch 24/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8815165876777251
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8329323825070883
# 77/77 - 15s - loss: 0.2507 - auc: 0.9609 - val_loss: 0.4850 - val_auc: 0.8805 - 15s/epoch - 197ms/step
# Epoch 25/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8759837876091012
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8251138413953089
# 77/77 - 15s - loss: 0.2466 - auc: 0.9624 - val_loss: 0.5464 - val_auc: 0.8753 - 15s/epoch - 197ms/step
# Epoch 26/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8798009907572215
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8302044849213852
# 77/77 - 15s - loss: 0.2149 - auc: 0.9717 - val_loss: 0.5616 - val_auc: 0.8769 - 15s/epoch - 199ms/step
# Epoch 27/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.890330466856812
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8788340922759688
# 77/77 - 15s - loss: 0.1896 - auc: 0.9780 - val_loss: 0.5363 - val_auc: 0.8851 - 15s/epoch - 197ms/step
# Epoch 28/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8994660204584933
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8587722312913482
# 77/77 - 15s - loss: 0.1810 - auc: 0.9798 - val_loss: 0.4997 - val_auc: 0.8977 - 15s/epoch - 200ms/step
# Epoch 29/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8936973258133001
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8494930835982473
# 77/77 - 15s - loss: 0.1623 - auc: 0.9839 - val_loss: 0.5569 - val_auc: 0.8901 - 15s/epoch - 197ms/step
# Epoch 30/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8617014432459094
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8460348827218833
# 77/77 - 15s - loss: 0.1376 - auc: 0.9885 - val_loss: 0.6564 - val_auc: 0.8592 - 15s/epoch - 198ms/step
# Epoch 31/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8548819454869079
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8380874645588109
# 77/77 - 15s - loss: 0.1264 - auc: 0.9898 - val_loss: 0.9060 - val_auc: 0.8376 - 15s/epoch - 199ms/step
# Epoch 32/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8690785100040745
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8231806856259127
# 77/77 - 15s - loss: 0.1381 - auc: 0.9882 - val_loss: 0.6650 - val_auc: 0.8655 - 15s/epoch - 198ms/step
# Epoch 33/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8731101627672578
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8454119769739669
# 77/77 - 15s - loss: 0.1077 - auc: 0.9924 - val_loss: 0.9018 - val_auc: 0.8553 - 15s/epoch - 199ms/step
# Epoch 34/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8790718620660075
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.841244952315491
# 77/77 - 15s - loss: 0.1053 - auc: 0.9921 - val_loss: 0.7550 - val_auc: 0.8692 - 15s/epoch - 198ms/step
# Epoch 35/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8712015611931977
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8542722742503652
# 77/77 - 15s - loss: 0.0859 - auc: 0.9950 - val_loss: 0.7136 - val_auc: 0.8641 - 15s/epoch - 199ms/step
# Epoch 36/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8751045441873432
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8341567144943725
# 77/77 - 15s - loss: 0.0703 - auc: 0.9968 - val_loss: 0.9032 - val_auc: 0.8555 - 15s/epoch - 199ms/step
# Epoch 37/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8546246059488324
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8358965546868289
# 77/77 - 15s - loss: 0.0833 - auc: 0.9947 - val_loss: 1.1992 - val_auc: 0.8333 - 15s/epoch - 199ms/step
# Epoch 38/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.887349617207437
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8438224933413523
# 77/77 - 15s - loss: 0.0636 - auc: 0.9972 - val_loss: 0.7251 - val_auc: 0.8792 - 15s/epoch - 198ms/step
# Epoch 39/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8816238124852567
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.846357075350116
# 77/77 - 15s - loss: 0.0631 - auc: 0.9976 - val_loss: 0.9273 - val_auc: 0.8660 - 15s/epoch - 199ms/step
# Epoch 40/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8846689970191505
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8442413437580547
# 77/77 - 15s - loss: 0.0504 - auc: 0.9982 - val_loss: 0.8957 - val_auc: 0.8676 - 15s/epoch - 197ms/step
# Epoch 41/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8848834466342134
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8477102843886932
# 77/77 - 15s - loss: 0.0557 - auc: 0.9976 - val_loss: 0.9827 - val_auc: 0.8681 - 15s/epoch - 198ms/step
# Epoch 42/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8766700263773025
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8611134977231721
# 77/77 - 15s - loss: 0.0548 - auc: 0.9975 - val_loss: 0.9868 - val_auc: 0.8558 - 15s/epoch - 197ms/step
# Epoch 43/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.889901567626686
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8625418850416703
# 77/77 - 15s - loss: 0.0607 - auc: 0.9977 - val_loss: 0.8856 - val_auc: 0.8764 - 15s/epoch - 199ms/step
# Epoch 44/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8903626342990714
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8685454076810722
# 77/77 - 15s - loss: 0.0496 - auc: 0.9980 - val_loss: 0.8710 - val_auc: 0.8778 - 15s/epoch - 198ms/step
# Epoch 45/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8830284574639189
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.862992954721196
# 77/77 - 15s - loss: 0.0303 - auc: 0.9994 - val_loss: 1.0177 - val_auc: 0.8684 - 15s/epoch - 197ms/step
# Epoch 46/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8835324140593168
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8688998195721281
# 77/77 - 15s - loss: 0.0358 - auc: 0.9990 - val_loss: 0.9533 - val_auc: 0.8661 - 15s/epoch - 196ms/step
# Epoch 47/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8831464047522035
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.851447718876192
# 77/77 - 15s - loss: 0.0445 - auc: 0.9983 - val_loss: 1.0055 - val_auc: 0.8644 - 15s/epoch - 196ms/step
# Epoch 48/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8900838497994896
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8671492396253973
# 77/77 - 15s - loss: 0.0367 - auc: 0.9986 - val_loss: 1.0721 - val_auc: 0.8721 - 15s/epoch - 196ms/step
# Epoch 49/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8751796015526152
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8554429074662772
# 77/77 - 15s - loss: 0.0382 - auc: 0.9984 - val_loss: 1.4353 - val_auc: 0.8438 - 15s/epoch - 196ms/step
# Epoch 50/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8631168107053246
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8475384483203023
# 77/77 - 15s - loss: 0.0467 - auc: 0.9987 - val_loss: 1.1814 - val_auc: 0.8420 - 15s/epoch - 196ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 1.3655740022659302 , AUC = 0.8249098658561707
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8631168107053246
# test 0.8475384483203023
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/0/050--1.181--0.047.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.7638888888888888
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ##20epoch

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=20,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7116724925478758
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6352564653320733
# 77/77 - 18s - loss: 1.4933 - auc: 0.5573 - val_loss: 0.6663 - val_auc: 0.7125 - 18s/epoch - 235ms/step
# Epoch 2/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7370204370483155
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7415800326488531
# 77/77 - 16s - loss: 0.6780 - auc: 0.6606 - val_loss: 0.6888 - val_auc: 0.7365 - 16s/epoch - 209ms/step
# Epoch 3/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7829555445947974
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7413652375633645
# 77/77 - 16s - loss: 0.5661 - auc: 0.7744 - val_loss: 0.6563 - val_auc: 0.7830 - 16s/epoch - 207ms/step
# Epoch 4/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.796058416075143
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7872884268407939
# 77/77 - 16s - loss: 0.5265 - auc: 0.8122 - val_loss: 0.6178 - val_auc: 0.7955 - 16s/epoch - 209ms/step
# Epoch 5/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8308421436383522
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7984362917776442
# 77/77 - 17s - loss: 0.5191 - auc: 0.8151 - val_loss: 0.6018 - val_auc: 0.8308 - 17s/epoch - 218ms/step
# Epoch 6/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8419291887371062
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8110232837872671
# 77/77 - 17s - loss: 0.4955 - auc: 0.8368 - val_loss: 0.5048 - val_auc: 0.8419 - 17s/epoch - 218ms/step
# Epoch 7/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.846732860114516
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8164146404330269
# 77/77 - 18s - loss: 0.4853 - auc: 0.8412 - val_loss: 0.4826 - val_auc: 0.8468 - 18s/epoch - 230ms/step
# Epoch 8/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.840235036778109
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8012286278889941
# 77/77 - 17s - loss: 0.4708 - auc: 0.8544 - val_loss: 0.5435 - val_auc: 0.8402 - 17s/epoch - 221ms/step
# Epoch 9/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8521155454525959
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8233740012028525
# 77/77 - 15s - loss: 0.4622 - auc: 0.8595 - val_loss: 0.4734 - val_auc: 0.8522 - 15s/epoch - 201ms/step
# Epoch 10/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8422723081212069
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7976415499613368
# 77/77 - 16s - loss: 0.4419 - auc: 0.8729 - val_loss: 0.6024 - val_auc: 0.8419 - 16s/epoch - 209ms/step
# Epoch 11/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8485985717655636
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8206031446000515
# 77/77 - 15s - loss: 0.4416 - auc: 0.8743 - val_loss: 0.4744 - val_auc: 0.8487 - 15s/epoch - 198ms/step
# Epoch 12/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8480838926894126
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8222785462668614
# 77/77 - 15s - loss: 0.4149 - auc: 0.8906 - val_loss: 0.4872 - val_auc: 0.8480 - 15s/epoch - 199ms/step
# Epoch 13/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8096545216701336
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7757754102586134
# 77/77 - 16s - loss: 0.3970 - auc: 0.8996 - val_loss: 0.7431 - val_auc: 0.8086 - 16s/epoch - 208ms/step
# Epoch 14/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.849928159378954
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.839440673597388
# 77/77 - 15s - loss: 0.3797 - auc: 0.9095 - val_loss: 0.5150 - val_auc: 0.8498 - 15s/epoch - 199ms/step
# Epoch 15/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8404923763161845
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8181759601340322
# 77/77 - 15s - loss: 0.3573 - auc: 0.9200 - val_loss: 0.5168 - val_auc: 0.8405 - 15s/epoch - 200ms/step
# Epoch 16/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8647895177028158
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8323739152848182
# 77/77 - 16s - loss: 0.3267 - auc: 0.9341 - val_loss: 0.5098 - val_auc: 0.8647 - 16s/epoch - 203ms/step
# Epoch 17/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8604361905170381
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8225577798779964
# 77/77 - 17s - loss: 0.3137 - auc: 0.9393 - val_loss: 0.4787 - val_auc: 0.8601 - 17s/epoch - 214ms/step
# Epoch 18/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8718877999613991
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8213119683821635
# 77/77 - 15s - loss: 0.3007 - auc: 0.9448 - val_loss: 0.4645 - val_auc: 0.8717 - 15s/epoch - 198ms/step
# Epoch 19/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8821384915614077
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8128705215224676
# 77/77 - 16s - loss: 0.2622 - auc: 0.9580 - val_loss: 0.4780 - val_auc: 0.8824 - 16s/epoch - 202ms/step
# Epoch 20/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8568977718684995
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8505455795171406
# 77/77 - 15s - loss: 0.2459 - auc: 0.9631 - val_loss: 0.5471 - val_auc: 0.8560 - 15s/epoch - 198ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.5539567470550537 , AUC = 0.8497830033302307
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8568977718684995
# test 0.8505455795171406
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/0/020--0.547--0.246.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.7893518518518519
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ##50epoch with LR0.01

# %%
# Create directory to save models
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn
rt_sv_dir = '/content/models'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  optimizer = keras.optimizers.Adam(lr=0.01)
  MERGM.compile(
      optimizer = optimizer ,
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(64,64))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(64,64))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=50,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.6205957410306449
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5011598934616376
# 77/77 - 17s - loss: 2.9552 - auc: 0.5317 - val_loss: 0.6672 - val_auc: 0.6175 - 17s/epoch - 224ms/step
# Epoch 2/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8228217280349982
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7546180943380015
# 77/77 - 15s - loss: 0.5832 - auc: 0.7470 - val_loss: 0.5382 - val_auc: 0.8229 - 15s/epoch - 197ms/step
# Epoch 3/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8234221869571745
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7868373571612681
# 77/77 - 15s - loss: 0.5303 - auc: 0.8012 - val_loss: 0.5201 - val_auc: 0.8227 - 15s/epoch - 196ms/step
# Epoch 4/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7837704531320366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.783550992353295
# 77/77 - 15s - loss: 0.5250 - auc: 0.8090 - val_loss: 0.6235 - val_auc: 0.7837 - 15s/epoch - 196ms/step
# Epoch 5/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8338444382492334
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7834650743190996
# 77/77 - 15s - loss: 0.5099 - auc: 0.8233 - val_loss: 0.4944 - val_auc: 0.8332 - 15s/epoch - 196ms/step
# Epoch 6/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8422508631597005
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7789328980152934
# 77/77 - 15s - loss: 0.5012 - auc: 0.8301 - val_loss: 0.5000 - val_auc: 0.8418 - 15s/epoch - 197ms/step
# Epoch 7/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8461967360768587
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.779276570152075
# 77/77 - 15s - loss: 0.4930 - auc: 0.8379 - val_loss: 0.5027 - val_auc: 0.8463 - 15s/epoch - 200ms/step
# Epoch 8/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8413930646994487
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8079302345562334
# 77/77 - 15s - loss: 0.4877 - auc: 0.8394 - val_loss: 0.5067 - val_auc: 0.8417 - 15s/epoch - 197ms/step
# Epoch 9/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.855182174947996
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7890497465417992
# 77/77 - 15s - loss: 0.4876 - auc: 0.8398 - val_loss: 0.4936 - val_auc: 0.8550 - 15s/epoch - 197ms/step
# Epoch 10/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8385194398576056
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8065555460091074
# 77/77 - 15s - loss: 0.4855 - auc: 0.8372 - val_loss: 0.5075 - val_auc: 0.8384 - 15s/epoch - 198ms/step
# Epoch 11/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.861958782783985
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.794591459747401
# 77/77 - 15s - loss: 0.4868 - auc: 0.8398 - val_loss: 0.4796 - val_auc: 0.8621 - 15s/epoch - 197ms/step
# Epoch 12/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8383264352040487
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8157917346851105
# 77/77 - 15s - loss: 0.4879 - auc: 0.8398 - val_loss: 0.4972 - val_auc: 0.8385 - 15s/epoch - 197ms/step
# Epoch 13/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8298985653320753
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8068347796202423
# 77/77 - 15s - loss: 0.4668 - auc: 0.8550 - val_loss: 0.5132 - val_auc: 0.8300 - 15s/epoch - 198ms/step
# Epoch 14/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8615084385923527
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.824963484835467
# 77/77 - 15s - loss: 0.4646 - auc: 0.8595 - val_loss: 0.4920 - val_auc: 0.8616 - 15s/epoch - 198ms/step
# Epoch 15/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8227359481889729
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8176819314374087
# 77/77 - 15s - loss: 0.4555 - auc: 0.8656 - val_loss: 0.6609 - val_auc: 0.8230 - 15s/epoch - 197ms/step
# Epoch 16/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.821277690806545
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8124409313514906
# 77/77 - 15s - loss: 0.4528 - auc: 0.8666 - val_loss: 0.5601 - val_auc: 0.8213 - 15s/epoch - 197ms/step
# Epoch 17/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8240226458793507
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.820109115903428
# 77/77 - 15s - loss: 0.4451 - auc: 0.8697 - val_loss: 0.5464 - val_auc: 0.8235 - 15s/epoch - 196ms/step
# Epoch 18/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8544959361797947
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8254145545149927
# 77/77 - 15s - loss: 0.4462 - auc: 0.8719 - val_loss: 0.4849 - val_auc: 0.8545 - 15s/epoch - 197ms/step
# Epoch 19/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8585919238274968
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8104862960735459
# 77/77 - 15s - loss: 0.4483 - auc: 0.8696 - val_loss: 0.4681 - val_auc: 0.8582 - 15s/epoch - 196ms/step
# Epoch 20/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8487701314576142
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8148036772918635
# 77/77 - 15s - loss: 0.4379 - auc: 0.8749 - val_loss: 0.4726 - val_auc: 0.8489 - 15s/epoch - 195ms/step
# Epoch 21/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8213741931333234
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8048371853251997
# 77/77 - 15s - loss: 0.4182 - auc: 0.8883 - val_loss: 0.5943 - val_auc: 0.8214 - 15s/epoch - 198ms/step
# Epoch 22/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7900752718148871
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7720594552796631
# 77/77 - 15s - loss: 0.4196 - auc: 0.8854 - val_loss: 0.7236 - val_auc: 0.7889 - 15s/epoch - 198ms/step
# Epoch 23/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8206021745190968
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7779233611134978
# 77/77 - 15s - loss: 0.4107 - auc: 0.8932 - val_loss: 0.5237 - val_auc: 0.8203 - 15s/epoch - 199ms/step
# Epoch 24/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8506251206279085
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8225792593865453
# 77/77 - 15s - loss: 0.3982 - auc: 0.9006 - val_loss: 0.4920 - val_auc: 0.8509 - 15s/epoch - 198ms/step
# Epoch 25/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8544744912182882
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.82137640690781
# 77/77 - 15s - loss: 0.3870 - auc: 0.9047 - val_loss: 0.5011 - val_auc: 0.8537 - 15s/epoch - 197ms/step
# Epoch 26/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8576269005597135
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8262737348569464
# 77/77 - 15s - loss: 0.3754 - auc: 0.9117 - val_loss: 0.4791 - val_auc: 0.8577 - 15s/epoch - 197ms/step
# Epoch 27/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8495850399948531
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8311710628060829
# 77/77 - 15s - loss: 0.3628 - auc: 0.9169 - val_loss: 0.4814 - val_auc: 0.8498 - 15s/epoch - 197ms/step
# Epoch 28/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8469687546910853
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8323309562677206
# 77/77 - 15s - loss: 0.3474 - auc: 0.9248 - val_loss: 0.5448 - val_auc: 0.8461 - 15s/epoch - 197ms/step
# Epoch 29/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.868671055735455
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.841599364206547
# 77/77 - 16s - loss: 0.3417 - auc: 0.9275 - val_loss: 0.4721 - val_auc: 0.8687 - 16s/epoch - 203ms/step
# Epoch 30/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8299629002165942
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8103144600051551
# 77/77 - 15s - loss: 0.3316 - auc: 0.9329 - val_loss: 0.5559 - val_auc: 0.8295 - 15s/epoch - 198ms/step
# Epoch 31/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8388411142801999
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8237391528481828
# 77/77 - 15s - loss: 0.3336 - auc: 0.9310 - val_loss: 0.5367 - val_auc: 0.8380 - 15s/epoch - 197ms/step
# Epoch 32/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8649396324333597
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8371638456912106
# 77/77 - 15s - loss: 0.3141 - auc: 0.9405 - val_loss: 0.5107 - val_auc: 0.8636 - 15s/epoch - 198ms/step
# Epoch 33/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8610580944007206
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.835853595669731
# 77/77 - 15s - loss: 0.2829 - auc: 0.9508 - val_loss: 0.5353 - val_auc: 0.8599 - 15s/epoch - 199ms/step
# Epoch 34/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8381870429542579
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8337486038319443
# 77/77 - 15s - loss: 0.2803 - auc: 0.9513 - val_loss: 0.6291 - val_auc: 0.8346 - 15s/epoch - 198ms/step
# Epoch 35/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.814576140335828
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8022811238078873
# 77/77 - 15s - loss: 0.2628 - auc: 0.9568 - val_loss: 0.6350 - val_auc: 0.8138 - 15s/epoch - 198ms/step
# Epoch 36/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8622697347258261
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8388392473580205
# 77/77 - 15s - loss: 0.2616 - auc: 0.9572 - val_loss: 0.4951 - val_auc: 0.8615 - 15s/epoch - 198ms/step
# Epoch 37/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8478908880358559
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8133860297276397
# 77/77 - 15s - loss: 0.2254 - auc: 0.9692 - val_loss: 0.6028 - val_auc: 0.8463 - 15s/epoch - 198ms/step
# Epoch 38/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8595140571722675
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8259515422287138
# 77/77 - 15s - loss: 0.2164 - auc: 0.9711 - val_loss: 0.5537 - val_auc: 0.8566 - 15s/epoch - 196ms/step
# Epoch 39/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8502605562823013
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8285290832545752
# 77/77 - 15s - loss: 0.2172 - auc: 0.9706 - val_loss: 0.6273 - val_auc: 0.8484 - 15s/epoch - 197ms/step
# Epoch 40/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7987926486671956
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7802216685282242
# 77/77 - 15s - loss: 0.2189 - auc: 0.9709 - val_loss: 0.7870 - val_auc: 0.7936 - 15s/epoch - 198ms/step
# Epoch 41/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8525658896442282
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8443594810550735
# 77/77 - 15s - loss: 0.2611 - auc: 0.9624 - val_loss: 0.5688 - val_auc: 0.8513 - 15s/epoch - 199ms/step
# Epoch 42/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.830027235101113
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8122153965117278
# 77/77 - 15s - loss: 0.2012 - auc: 0.9758 - val_loss: 0.8477 - val_auc: 0.8249 - 15s/epoch - 199ms/step
# Epoch 43/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8464540756149342
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8248346077841741
# 77/77 - 15s - loss: 0.1970 - auc: 0.9762 - val_loss: 0.6522 - val_auc: 0.8419 - 15s/epoch - 198ms/step
# Epoch 44/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.834691514228732
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8108514477188762
# 77/77 - 15s - loss: 0.1701 - auc: 0.9822 - val_loss: 0.7704 - val_auc: 0.8309 - 15s/epoch - 198ms/step
# Epoch 45/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7939675323282794
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7374559670074748
# 77/77 - 15s - loss: 0.1643 - auc: 0.9832 - val_loss: 1.1308 - val_auc: 0.7828 - 15s/epoch - 197ms/step
# Epoch 46/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8392914584718321
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8206568433714237
# 77/77 - 15s - loss: 0.1460 - auc: 0.9869 - val_loss: 0.8704 - val_auc: 0.8340 - 15s/epoch - 197ms/step
# Epoch 47/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8514185842036414
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.845111263854283
# 77/77 - 15s - loss: 0.1541 - auc: 0.9852 - val_loss: 0.8248 - val_auc: 0.8469 - 15s/epoch - 196ms/step
# Epoch 48/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8484162895927603
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8229229315233269
# 77/77 - 15s - loss: 0.1386 - auc: 0.9877 - val_loss: 0.7993 - val_auc: 0.8452 - 15s/epoch - 197ms/step
# Epoch 49/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.840524543758444
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8236210155511643
# 77/77 - 15s - loss: 0.1338 - auc: 0.9887 - val_loss: 0.8884 - val_auc: 0.8348 - 15s/epoch - 197ms/step
# Epoch 50/50
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8483519547082412
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8331364378383022
# 77/77 - 15s - loss: 0.1374 - auc: 0.9879 - val_loss: 1.0522 - val_auc: 0.8414 - 15s/epoch - 197ms/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.9798466563224792 , AUC = 0.8250923752784729
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:78: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.8483519547082412
# test 0.8331364378383022
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/0/050--1.052--0.137.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(64,64))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
# Out:
# 0
# Num_samples: 432
# acc:  0.7824074074074074
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ##use resnet50

# %%
class CustomDataset(tf.keras.utils.Sequence):
  def __init__(self,imgfiles,labels,batch_size,target_size=(224,224),shuffle=False,scale=255,n_classes=1,n_channels=3):
    self.batch_size = batch_size
    self.dim        = target_size
    self.labels     = labels
    self.imgfiles   = imgfiles
    self.n_classes  = n_classes
    self.shuffle    = shuffle
    self.n_channels = n_channels
    self.scale      = scale

    self.c          = 0
    self.on_epoch_end()

  def __len__(self):
    # returns the number of batches
    return int(np.floor(len(self.imgfiles) / self.batch_size))

  def __getitem__(self, index):
    # returns one batch
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

    # Generate data
    X, y = self.__data_generation(indexes)
    return X, y

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.imgfiles))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)
  
  def __data_generation(self, list_IDs_temp):
    X = np.empty((self.batch_size, *self.dim, self.n_channels))
    y = np.empty((self.batch_size), dtype=int)

    # Generate data
    for i, ID in enumerate(list_IDs_temp):
        # Store sample
        img   = cv2.imread(self.imgfiles[ID])
        img   = cv2.resize(img,self.dim,interpolation = cv2.INTER_CUBIC)
        X[i,] = img / self.scale

        # Store class
        y[i] = self.labels[ID]

        self.c +=1
    return X, y #keras.utils.to_categorical(y, num_classes=self.n_classes)


class CustomPipeline(tf.keras.utils.Sequence):
  def __init__(self,data_x,data_y,batch_size=48,shuffle=False,n_classes=1):
    self.features   = data_x
    self.labels     = data_y
    self.batch_size = 48
    self.shuffle    = shuffle
    self.n_features = self.features.shape[1]
    self.n_classes  = 1
    self.on_epoch_end()

  def __len__(self):
    return int(np.floor(len(self.features) / self.batch_size))

  def __getitem__(self,index):
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
    X, y = self.__data_generation(indexes)
    return X, y

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.features))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)

  def __data_generation(self,indexes):
    X = np.empty((self.batch_size, self.n_features))
    y = np.empty((self.batch_size), dtype=int)

    for i, ID in enumerate(indexes):
      X[i,] = self.features[ID]
      y[i,] = self.labels[ID]
    return X, y

class MultipleInputGenerator(tf.keras.utils.Sequence):
  """Wrapper of two generatos for the combined input model"""

  def __init__(self, X1, X2, Y, batch_size,target_size=(224,224)):
      self.genX1 = CustomPipeline(X1, Y, batch_size=batch_size,shuffle=False)
      self.genX2 = CustomDataset (X2, Y, batch_size=batch_size,shuffle=False,target_size=target_size)

  def __len__(self):
      return self.genX1.__len__()

  def __getitem__(self, index):
      X1_batch, Y_batch = self.genX1.__getitem__(index)
      X2_batch, Y_batch = self.genX2.__getitem__(index)
      X_batch = [X1_batch, X2_batch]
      return X_batch, Y_batch

class TripleInputGenerator(tf.keras.utils.Sequence):
  """Wrapper of two generatos for the combined input model"""

  def __init__(self, X1, X2, X3, Y, batch_size,target_size=(224,224)):
      self.genX1 = CustomPipeline(X1, Y, batch_size=batch_size,shuffle=False)
      self.genX2 = CustomDataset (X2, Y, batch_size=batch_size,shuffle=False,target_size=target_size)
      self.genX3 = CustomPipeline(X3, Y, batch_size=batch_size,shuffle=False)
  def __len__(self):
      return self.genX1.__len__()

  def __getitem__(self, index):
      X1_batch, Y_batch = self.genX1.__getitem__(index)
      X2_batch, Y_batch = self.genX2.__getitem__(index)
      X3_batch, Y_batch = self.genX3.__getitem__(index)

      X_batch = [X1_batch,X1_batch,X2_batch, X3_batch]
      return X_batch, Y_batch

# %%
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback
class Evaluation(keras.callbacks.Callback):
  
  def __init__(self, val_data_gen, val_labels, test_data_gen, test_labels):
    super(Callback, self).__init__()
    self.test_data = test_data_gen
    self.val_labels = val_labels
    self.val_data = val_data_gen
    self.test_labels = test_labels

  def on_epoch_end(self, epoch, logs=None):
    y_preds = self.model.predict_generator(self.val_data)
    print(' | val_auc:', roc_auc_score(self.val_labels[:len(y_preds)], y_preds))

    y_preds = self.model.predict_generator(self.test_data)
    print(' | test_auc:', roc_auc_score(self.test_labels[:len(y_preds)], y_preds))

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

#model = ResNet50(weights='imagenet', include_top=False)

# %%
def build_model():
  '''Function to build ensemble model'''
  # First Model
  inp1   = Input(shape=39)
  lay1   = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(inp1)
  lay2   = BatchNormalization()(lay1)
  lay3   = Dropout(0.5)(lay2)
  lay4   = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(lay3)
  lay5   = BatchNormalization()(lay4)
  lay6   = Dropout(0.5)(lay5)

  #first +1 model
  inp11   = Input(shape=39)
  lay11   = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(inp1)
  lay21   = BatchNormalization()(lay1)
  lay31   = Dropout(0.5)(lay2)
  lay41   = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(lay3)
  lay51   = BatchNormalization()(lay4)
  lay61   = Dropout(0.5)(lay5)

  # first merge input models
  merge1 = concatenate([lay6,lay61])

# resnet
  inp2   = ResNet50(weights='imagenet', include_top=False)
  x = inp2.output

#first branch 
  x11 = GlobalAveragePooling2D()(x)
  x21   = BatchNormalization()(x11)
  x31   = Dropout(0.5)(x21)

#second branch
  x12 = GlobalAveragePooling2D()(x)
  x22   = BatchNormalization()(x12)
  x32   = Dropout(0.5)(x22)

#merge resnet 
  mergeXX = concatenate([x31,x32])
  x13   = BatchNormalization()(mergeXX)
  x23   = Dropout(0.5)(x13)


  # Second Model
#  inp2   = Input(shape=(64,64,3))
#  lay1_  = Conv2D(32, (3, 3), strides=(2, 2))(inp2)
#  lay2_  = AveragePooling2D((2, 2), strides=(2,2))(lay1_)
#  lay3_  = BatchNormalization()(lay2_)
#  lay4_  = Activation('relu')(lay3_)

 # lay5_  = Conv2D(64, (3, 3), padding="same") (lay4_)
 # lay6_  = AveragePooling2D((2, 2), strides=(2,2)) (lay5_)
 # lay7_  = BatchNormalization()(lay6_)
  #lay8_  = Activation('relu')(lay7_)

 # lay9_  = Conv2D(64, (3, 3), padding="same") (lay8_)
 # lay10_ = AveragePooling2D((2, 2), strides=(2,2)) (lay9_)
  #lay11_ = BatchNormalization()(lay10_)
  #lay12_ = Activation('relu')(lay11_)

 # lay13_ = Flatten()(lay12_)
 # lay14_ = Dense(units=256,activation='relu',kernel_initializer='GlorotUniform')(lay13_)
 # lay15_ = Dropout(rate=0.5)(lay14_)

  # Third model
  inp3   = Input(shape=2)
  lay31  = Dense(units=5,activation='relu',kernel_initializer='GlorotUniform')(inp3)
  lay32  = BatchNormalization()(lay31)
  lay33  = Dropout(0.5)(lay32)
  lay34  = Dense(units=64,activation='relu',kernel_initializer='GlorotUniform')(lay33)
  lay35  = BatchNormalization()(lay34)
  lay36  = Dropout(0.5)(lay35)

 # second merge input models
  merge2 = concatenate([merge1,lay36])

  # merge input models
  merge3 = concatenate([x23, merge2])

  # interpretation model
  hidden1 = Dense(256, activation='relu')(merge3)
  hidden2  = BatchNormalization()(hidden1)
  hidden3  = Dropout(0.5)(hidden2)
  output  = Dense(1, activation='sigmoid')(hidden3)
  MERGM   = Model(inputs=[inp1,inp11 ,inp2.input,inp3], outputs=output)
  
  for layer in inp2.layers:
    layer.trainable = False


  return MERGM

# %%
# Create directory to save models
import matplotlib.pyplot as plt

rt_sv_dir = '/content/models/resnet'
# !rm -r {rt_sv_dir}
os.mkdir(rt_sv_dir)

# Run each split
for RUN in range(NUM_shuf):
  MERGM = build_model()

  #optimizer = keras.optimizers.Adam(lr=0.01)

  MERGM.compile(
      optimizer = 'Adam',
      loss = 'BinaryCrossentropy',
      metrics=['AUC'])
  

  tfeatures = DATA_train[RUN]['MFCCS'][:]
  textra    = DATA_train[RUN]['EXTRA'][:]
  timgs     = DATA_train[RUN]['MEL'][:]
  labels    = DATA_train[RUN]['LABELS'][:]

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  val_features= DATA_val[RUN]['MFCCS'][:]
  val_extra   = DATA_val[RUN]['EXTRA'][:]
  val_imgs    = DATA_val[RUN]['MEL'][:]
  val_labels  = DATA_val[RUN]['LABELS'][ :]


#  tfeatures = DATA_train[RUN]['MFCCS'][:]
#  textra    = DATA_train[RUN]['EXTRA'][:]
#  timgs     = DATA_train[RUN]['MEL'][:]
#  labels    = DATA_train[RUN]['LABELS'][:]
#
#  test_features= DATA_test[RUN]['MFCCS'][ : ]
#  test_extra   = DATA_test[RUN]['EXTRA'][ : ]
#  test_imgs    = DATA_test[RUN]['MEL'][ : ]
#  test_labels  = DATA_test[RUN]['LABELS'][ : ]
#                                        
#  val_features= DATA_val[RUN]['MFCCS'][  :]
#  val_extra   = DATA_val[RUN]['EXTRA'][:]
#  val_imgs    = DATA_val[RUN]['MEL'][  :]
#  val_labels  = DATA_val[RUN]['LABELS'][  :]

  imgs_em      = TripleInputGenerator(tfeatures,timgs,textra,labels,batch_size=48,target_size=(224,224))
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(224,224))
  VAL         = TripleInputGenerator(val_features,val_imgs,val_extra,val_labels,batch_size=48,target_size=(224,224))


  evaluator = Evaluation(VAL, val_labels, TEST, test_labels)
  checkpointer = keras.callbacks.ModelCheckpoint(filepath=os.path.join(os.path.join(rt_sv_dir, str(RUN)),
                "{epoch:03d}--{val_loss:.3f}--{loss:.3f}.hdf5"), save_best_only=False)
  os.mkdir(os.path.join(rt_sv_dir, str(RUN)))
  history =  MERGM.fit_generator(
                  imgs_em,
                  epochs=30,
                  validation_data=VAL, 
                  verbose=2, 
                  callbacks=[evaluator, checkpointer])
  print(history.history.keys())
  plt.plot(history.history['auc'])
  plt.plot(history.history['val_auc'])
  plt.title('model accuracy')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.savefig('accuracy.png')

  plt.show()
  # summarize history for loss
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.savefig('loss.png')

  plt.show()

  MERGM_Record1 = MERGM.evaluate_generator(
    TEST
  )
  print()
  print('Results: Loss = {} , AUC = {} '.format(MERGM_Record1[0],MERGM_Record1[1]))

  print()
  from sklearn.metrics import roc_auc_score

  y_val  = val_labels
  y_preds_val = MERGM.predict_generator(VAL)
  print('val:', roc_auc_score(y_val[:len(y_preds_val)], y_preds_val))

  y_test  = test_labels
  y_preds_test = MERGM.predict(TEST)
  print('test', roc_auc_score(y_test[:len(y_preds_test)], y_preds_test))
  print()
  print('-----------------------------------------------------------------')
  from sklearn.metrics import ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_predictions(y_test[:len(y_preds_test)], y_preds_test>0.5)
  plt.savefig('ConfusionMatrix.png')
  plt.show()
# Out:
# rm: cannot remove '/content/models/resnet': No such file or directory
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.6042117904398362
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5637297018644214
# 77/77 - 431s - loss: 0.8097 - auc: 0.7101 - val_loss: 0.7842 - val_auc: 0.6038 - 431s/epoch - 6s/step
# Epoch 2/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7155540305805151
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.5903428129564396
# 77/77 - 429s - loss: 0.6575 - auc: 0.7571 - val_loss: 0.6473 - val_auc: 0.7146 - 429s/epoch - 6s/step
# Epoch 3/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.76170358774206
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.6269438955236704
# 77/77 - 429s - loss: 0.5982 - auc: 0.7738 - val_loss: 0.5998 - val_auc: 0.7617 - 429s/epoch - 6s/step
# Epoch 4/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.7785378825245008
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7070624624108601
# 77/77 - 435s - loss: 0.5712 - auc: 0.7859 - val_loss: 0.5877 - val_auc: 0.7786 - 435s/epoch - 6s/step
# Epoch 5/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8198623233471296
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7359094423919581
# 77/77 - 424s - loss: 0.5381 - auc: 0.8069 - val_loss: 0.5516 - val_auc: 0.8193 - 424s/epoch - 6s/step
# Epoch 6/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8238296412257939
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7634246928430278
# 77/77 - 426s - loss: 0.5192 - auc: 0.8174 - val_loss: 0.5320 - val_auc: 0.8235 - 426s/epoch - 6s/step
# Epoch 7/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8388625592417062
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7789758570323913
# 77/77 - 433s - loss: 0.5121 - auc: 0.8232 - val_loss: 0.4992 - val_auc: 0.8390 - 433s/epoch - 6s/step
# Epoch 8/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.855696854024147
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.7902525990205345
# 77/77 - 432s - loss: 0.5144 - auc: 0.8263 - val_loss: 0.4879 - val_auc: 0.8554 - 432s/epoch - 6s/step
# Epoch 9/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8509146276082434
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.796116504854369
# 77/77 - 414s - loss: 0.4969 - auc: 0.8335 - val_loss: 0.4808 - val_auc: 0.8510 - 414s/epoch - 5s/step
# Epoch 10/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8577555703287513
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8096915542572385
# 77/77 - 423s - loss: 0.4944 - auc: 0.8354 - val_loss: 0.4699 - val_auc: 0.8578 - 423s/epoch - 5s/step
# Epoch 11/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8549033904484141
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8067059025689493
# 77/77 - 427s - loss: 0.4799 - auc: 0.8457 - val_loss: 0.4664 - val_auc: 0.8551 - 427s/epoch - 6s/step
# Epoch 12/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8670626836224828
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8136008248131282
# 77/77 - 418s - loss: 0.4709 - auc: 0.8555 - val_loss: 0.4510 - val_auc: 0.8672 - 418s/epoch - 5s/step
# Epoch 13/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8629452510132745
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8237606323567317
# 77/77 - 435s - loss: 0.4740 - auc: 0.8498 - val_loss: 0.4599 - val_auc: 0.8630 - 435s/epoch - 6s/step
# Epoch 14/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8728957131521949
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8155125010739754
# 77/77 - 422s - loss: 0.4746 - auc: 0.8498 - val_loss: 0.4534 - val_auc: 0.8730 - 422s/epoch - 5s/step
# Epoch 15/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8711801162316914
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8139659764584586
# 77/77 - 427s - loss: 0.4602 - auc: 0.8595 - val_loss: 0.4423 - val_auc: 0.8712 - 427s/epoch - 6s/step
# Epoch 16/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8647251828182969
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8223000257754103
# 77/77 - 414s - loss: 0.4552 - auc: 0.8624 - val_loss: 0.4616 - val_auc: 0.8647 - 414s/epoch - 5s/step
# Epoch 17/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8760910124166327
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8152547469713893
# 77/77 - 422s - loss: 0.4666 - auc: 0.8555 - val_loss: 0.4426 - val_auc: 0.8759 - 422s/epoch - 5s/step
# Epoch 18/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8751045441873431
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8127201649626256
# 77/77 - 434s - loss: 0.4598 - auc: 0.8599 - val_loss: 0.4405 - val_auc: 0.8751 - 434s/epoch - 6s/step
# Epoch 19/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8727241534601445
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8156843371423662
# 77/77 - 429s - loss: 0.4493 - auc: 0.8678 - val_loss: 0.4354 - val_auc: 0.8727 - 429s/epoch - 6s/step
# Epoch 20/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8739036263429906
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8139444969499098
# 77/77 - 424s - loss: 0.4544 - auc: 0.8644 - val_loss: 0.4446 - val_auc: 0.8739 - 424s/epoch - 6s/step
# Epoch 21/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8637601595505136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.815276226479938
# 77/77 - 417s - loss: 0.4397 - auc: 0.8731 - val_loss: 0.4496 - val_auc: 0.8638 - 417s/epoch - 5s/step
# Epoch 22/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8735390619973837
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8135793453045794
# 77/77 - 430s - loss: 0.4474 - auc: 0.8668 - val_loss: 0.4627 - val_auc: 0.8736 - 430s/epoch - 6s/step
# Epoch 23/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8735176170358775
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8055460091073117
# 77/77 - 415s - loss: 0.4448 - auc: 0.8708 - val_loss: 0.4513 - val_auc: 0.8735 - 415s/epoch - 5s/step
# Epoch 24/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8779996139906929
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8067703410945959
# 77/77 - 416s - loss: 0.4473 - auc: 0.8692 - val_loss: 0.4426 - val_auc: 0.8780 - 416s/epoch - 5s/step
# Epoch 25/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8795865411421587
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8182618781682276
# 77/77 - 432s - loss: 0.4431 - auc: 0.8724 - val_loss: 0.4287 - val_auc: 0.8797 - 432s/epoch - 6s/step
# Epoch 26/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8727241534601445
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8068347796202422
# 77/77 - 427s - loss: 0.4290 - auc: 0.8785 - val_loss: 0.4485 - val_auc: 0.8726 - 427s/epoch - 6s/step
# Epoch 27/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8753189938024062
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8122261362660022
# 77/77 - 411s - loss: 0.4330 - auc: 0.8777 - val_loss: 0.4427 - val_auc: 0.8755 - 411s/epoch - 5s/step
# Epoch 28/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8822671613304454
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8264455709253372
# 77/77 - 418s - loss: 0.4299 - auc: 0.8789 - val_loss: 0.4394 - val_auc: 0.8823 - 418s/epoch - 5s/step
# Epoch 29/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.8712873410392228
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.82137640690781
# 77/77 - 416s - loss: 0.4355 - auc: 0.8760 - val_loss: 0.4406 - val_auc: 0.8716 - 416s/epoch - 5s/step
# Epoch 30/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
#  | val_auc: 0.876262572108683
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   app.launch_new_instance()
#  | test_auc: 0.8191210585101814
# 77/77 - 426s - loss: 0.4420 - auc: 0.8713 - val_loss: 0.4474 - val_auc: 0.8762 - 426s/epoch - 6s/step
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:88: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# Results: Loss = 0.5519694089889526 , AUC = 0.8195828199386597
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:97: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# val: 0.876262572108683
# test 0.8191210585101814
#
# -----------------------------------------------------------------

# %%
# Calculate ROC curves for each run
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from scipy import interp
import sklearn

# EDIT MODEL PATHS TO USE
models = {0: '/content/models/0/030--0.459--0.483.hdf5'
          }

tprs = []
base_fpr = np.linspace(0, 1, 101)
for iii in range(1):
  print(iii)

  test_features= DATA_test[RUN]['MFCCS'][:]
  test_extra   = DATA_test[RUN]['EXTRA'][:]
  test_imgs    = DATA_test[RUN]['MEL'][:]
  test_labels  = DATA_test[RUN]['LABELS'][:]
                                        
  TEST          = TripleInputGenerator(test_features,test_imgs,test_extra,test_labels,batch_size=48,target_size=(224,224))

  model = keras.models.load_model(models[iii])
  y_score = model.predict(TEST)
  fpr, tpr, _ = roc_curve(test_labels[:len(y_score)], y_score)
  print('Num_samples:', len(y_score))

  print('acc: ', sklearn.metrics.accuracy_score(test_labels[:len(y_score)], y_score>0.5))

  plt.plot(fpr, tpr, 'b', alpha=0.15)
  tpr = interp(base_fpr, fpr, tpr)
  tpr[0] = 0.0
  tprs.append(tpr)

tprs = np.array(tprs)
mean_tprs = tprs.mean(axis=0)
std = tprs.std(axis=0)

tprs_upper = np.minimum(mean_tprs + std, 1)
tprs_lower = mean_tprs - std

plt.plot(base_fpr, mean_tprs, 'b')
plt.fill_between(base_fpr, tprs_lower, tprs_upper, color='grey', alpha=0.3)

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.axes().set_aspect('equal', 'datalim')
plt.savefig('roc_curve.png')
plt.show()
